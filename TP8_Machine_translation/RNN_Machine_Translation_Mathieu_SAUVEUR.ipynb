# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Machine Translation
# In this notebook, we aim to convert English phrases to French using RNN on Deep Learning Neural Network

# %% [markdown]
# #Introduction
# In this notebook, you will build a deep neural network that functions as part of an end-to-end machine translation pipeline. Your completed pipeline will accept English text as input and return the French translation.

# %%
#Now importing modules
# !pip install helper
# !pip install keras
# !pip install tensorflow
import helper
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model, Sequential
from keras.layers import GRU, Input, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional, Dropout, LSTM
from keras.layers import Embedding
from keras.optimizers import Adam
from keras.losses import sparse_categorical_crossentropy
# Out:
# Requirement already satisfied: helper in /usr/local/lib/python3.10/dist-packages (2.5.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from helper) (6.0.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import tensorflow as tf

# %% [markdown]
# #Load Data
# The small_vocab_en file contains English sentences with their French translations in the small_vocab_fr file. Load the English and French data from these files from running the cell below.

# %%
english_path='https://raw.githubusercontent.com/projjal1/datasets/master/small_vocab_en.txt'
french_path='https://raw.githubusercontent.com/projjal1/datasets/master/small_vocab_fr.txt'

# %% [markdown]
# Load the dataset and split file by lines

# %%
import os

def load_data(path):
  input_file = os.path.join(path)
  with open(input_file, "r") as f:
    data = f.read()

  return data.split('\n')

# %%
#Using helper to inport dataset
english_data=tf.keras.utils.get_file('file1',english_path)
french_data=tf.keras.utils.get_file('file2',french_path)

# %%
#Now loading data
english_sentences=load_data(english_data)
french_sentences=load_data(french_data)

# %%
len(french_sentences), len(english_sentences)
# Out:
# (137860, 137860)

# %%
english_sentences
# Out:
# ['new jersey is sometimes quiet during autumn , and it is snowy in april .',
#  'the united states is usually chilly during july , and it is usually freezing in november .',
#  'california is usually quiet during march , and it is usually hot in june .',
#  'the united states is sometimes mild during june , and it is cold in september .',
#  'your least liked fruit is the grape , but my least liked is the apple .',
#  'his favorite fruit is the orange , but my favorite is the grape .',
#  'paris is relaxing during december , but it is usually chilly in july .',
#  'new jersey is busy during spring , and it is never hot in march .',
#  'our least liked fruit is the lemon , but my least liked is the grape .',
#  'the united states is sometimes busy during january , and it is sometimes warm in november .',
#  'the lime is her least liked fruit , but the banana is my least liked .',
#  'he saw a old yellow truck .',
#  'india is rainy during june , and it is sometimes warm in november .',
#  'that cat was my most loved animal .',
#  'he dislikes grapefruit , limes , and lemons .',
#  'her least liked fruit is the lemon , but his least liked is the grapefruit .',
#  'california is never cold during february , but it is sometimes freezing in june .',
#  'china is usually pleasant during autumn , and it is usually quiet in october .',
#  'paris is never freezing during november , but it is wonderful in october .',
#  'the united states is never rainy during january , but it is sometimes mild in october .',
#  'china is usually pleasant during november , and it is never quiet in october .',
#  'the united states is never nice during february , but it is sometimes pleasant in april .',
#  'india is never busy during autumn , and it is mild in spring .',
#  'paris is mild during summer , but it is usually busy in april .',
#  'france is never cold during september , and it is snowy in october .',
#  'california is never cold during may , and it is sometimes chilly in march .',
#  'he dislikes lemons , grapes , and mangoes.',
#  'their favorite fruit is the mango , but our favorite is the pear .',
#  'france is sometimes quiet during may , and it is never chilly in august .',
#  'paris is never pleasant during september , and it is beautiful in autumn .',
#  'he dislikes apples , peaches , and grapes .',
#  'california is usually freezing during december , and it is busy in april .',
#  'your most feared animal is that shark .',
#  'paris is usually wet during august , and it is never dry in november .',
#  'paris is usually beautiful during september , and it is usually snowy in november .',
#  'the united states is never wet during january , but it is usually hot in october .',
#  'we like oranges , mangoes , and grapes .',
#  'they like pears , apples , and mangoes .',
#  'she dislikes that little red truck .',
#  'the grapefruit is my most loved fruit , but the banana is her most loved .',
#  'france is snowy during may , and it is never busy in autumn .',
#  'china is usually mild during winter , but it is never busy in february .',
#  'china is never nice during july , but it is usually snowy in spring .',
#  'california is busy during november , but it is rainy in autumn .',
#  'china is warm during spring , and it is sometimes cold in february .',
#  'california is usually beautiful during winter , but it is never busy in february .',
#  'france is wonderful during november , but it is sometimes hot in september .',
#  'india is usually pleasant during november , but it is never relaxing in july .',
#  'the united states is never freezing during autumn , but it is never busy in june .',
#  'paris is sometimes warm during june , but it is usually hot in july .',
#  'paris is never hot during summer , and it is usually mild in winter .',
#  'she disliked a rusty yellow car .',
#  'france is usually quiet during november , but it is sometimes warm in february .',
#  'new jersey is never wet during november , and it is mild in august .',
#  'we like peaches , pears , and strawberries .',
#  'the orange is her least liked fruit , but the grapefruit is their least liked .',
#  'china is never rainy during november , and it is quiet in january .',
#  'china is relaxing during march , but it is sometimes snowy in september .',
#  'paris is wonderful during march , but it is usually pleasant in june .',
#  'new jersey is chilly during autumn , and it is sometimes pleasant in spring .',
#  'california is never freezing during october , but it is usually quiet in june .',
#  'new jersey is freezing during winter , but it is sometimes wonderful in january .',
#  'i like grapes , pears , and strawberries .',
#  'the lemon is my most loved fruit , but the strawberry is our most loved .',
#  'china is usually dry during march , but it is nice in november .',
#  'paris is pleasant during december , but it is never nice in november .',
#  'china is freezing during july , but it is relaxing in january .',
#  'the apple is our least favorite fruit , but the orange is her least favorite .',
#  'he dislikes grapes , grapefruit , and bananas.',
#  'he dislikes apples , mangoes , and strawberries .',
#  'china is hot during july , but it is never pleasant in january .',
#  'india is usually dry during april , and it is freezing in february .',
#  'she is going to the united states next summer .',
#  'france is sometimes rainy during february , and it is usually quiet in spring .',
#  'i plan to visit california next may .',
#  'california is never wet during november , and it is sometimes pleasant in september .',
#  'they like lemons , limes , and grapefruit .',
#  'the united states is never beautiful during march , and it is usually relaxing in summer .',
#  'elephants were his most feared animals .',
#  'the strawberry is their least favorite fruit , but the apple is our least favorite.',
#  'they are going to france next june .',
#  'he likes strawberries , oranges , and limes .',
#  'california is never pleasant during winter , and it is sometimes wonderful in december .',
#  'the apple is our least favorite fruit , but the mango is their least favorite .',
#  'she likes strawberries , oranges , and bananas .',
#  'california is beautiful during january , and it is pleasant in february .',
#  'they dislike grapes , mangoes , and limes .',
#  'she dislikes lemons , grapes , and oranges .',
#  'our least favorite fruit is the banana , but your least favorite is the grape .',
#  'california is never cold during december , but it is usually warm in may .',
#  'california is never busy during february , and it is usually hot in june .',
#  'the united states is sometimes beautiful during november , and it is never rainy in march .',
#  'new jersey is sometimes hot during march , and it is beautiful in fall .',
#  'the grapefruit is our least favorite fruit , but the orange is your least favorite .',
#  'i like grapefruit , limes , and pears .',
#  'she dislikes lemons , strawberries , and grapes .',
#  'paris is usually chilly during fall , but it is sometimes rainy in july .',
#  'she likes mangoes , apples , and bananas .',
#  'she is driving the old yellow truck .',
#  'we like peaches , mangoes , and oranges .',
#  'new jersey is usually quiet during fall , but it is usually warm in april .',
#  'california is never rainy during winter , and it is usually mild in summer .',
#  'california is sometimes cold during winter , but it is sometimes chilly in autumn .',
#  'she likes lemons , pears , and oranges.',
#  'we like strawberries , bananas , and oranges .',
#  'india is never snowy during september , but it is sometimes dry in spring .',
#  'india is sometimes rainy during january , and it is pleasant in february .',
#  'paris is never relaxing during march , but it is usually freezing in autumn .',
#  'india is chilly during summer , and it is sometimes beautiful in september .',
#  'she likes peaches , limes , and mangoes .',
#  'india is never chilly during october , but it is usually relaxing in november .',
#  'i like peaches , grapes , and lemons .',
#  'she likes mangoes , grapefruit , and pears .',
#  'the united states is usually dry during winter , but it is sometimes snowy in february .',
#  'china is usually nice during april , and it is never snowy in august .',
#  'she dislikes oranges and grapefruit .',
#  'paris is sometimes wonderful during autumn , and it is warm in november .',
#  'the grapefruit is her least favorite fruit , but the banana is their least favorite .',
#  'the grapefruit is his least liked fruit , but the grape is my least liked.',
#  'paris is never busy during summer , but it is never freezing in november .',
#  'china is sometimes pleasant during march , but it is usually nice in may .',
#  'india is sometimes cold during march , but it is sometimes hot in january .',
#  'new jersey is rainy during june , and it is sometimes nice in november .',
#  'the strawberry is his least favorite fruit , but the peach is our least favorite .',
#  'paris is usually snowy during winter , and it is sometimes beautiful in august .',
#  'france is never chilly during march , and it is wet in april .',
#  'their least liked fruit is the banana , but her least liked is the peach .',
#  'china is cold during fall , but it is usually relaxing in november .',
#  'new jersey is usually beautiful during april , and it is never relaxing in december .',
#  'he dislikes grapefruit , mangoes , and lemons .',
#  'new jersey is usually freezing during november , but it is usually relaxing in autumn .',
#  'the strawberry is my most loved fruit , but the lemon is her most loved.',
#  'paris is sometimes pleasant during autumn , and it is wonderful in september .',
#  'her most loved fruit is the lemon , but your most loved is the mango .',
#  'the mango is your least liked fruit , but the apple is his least liked .',
#  'the pear is my most loved fruit , but the lemon is his most loved .',
#  'he drives a new blue car .',
#  'the united states is warm during spring , but it is wet in august .',
#  'paris is usually freezing during october , and it is usually nice in april .',
#  'the peach is your most loved fruit , but the banana is my most loved .',
#  'you like grapes , peaches , and strawberries .',
#  'new jersey is sometimes nice during winter , but it is hot in spring .',
#  'paris is usually beautiful during september , but it is usually busy in spring .',
#  'china is usually snowy during autumn , but it is usually hot in may .',
#  'that bird is her most feared animal .',
#  'she dislikes apples , peaches , and bananas .',
#  'i plan to visit california next october .',
#  'you like limes , bananas , and grapefruit.',
#  'paris is never quiet during spring , but it is usually hot in march .',
#  'paris is rainy during winter , and it is sometimes warm in april .',
#  'you like pears , grapefruit , and limes .',
#  'paris is warm during january , and it is rainy in october .',
#  'france is sometimes quiet during december , and it is never snowy in january .',
#  'paris is sometimes relaxing during summer , but it is usually mild in november .',
#  'she likes bananas and grapes .',
#  'the lime is her least liked fruit , but the orange is his least liked .',
#  'california is never hot during fall , but it is usually relaxing in april .',
#  'new jersey is busy during december , and it is usually mild in august .',
#  'china is never mild during april , and it is sometimes wet in spring .',
#  'the united states is never snowy during february , and it is usually pleasant in autumn .',
#  'india is never dry during january , and it is never hot in february .',
#  'paris is usually wonderful during autumn , and it is busy in spring .',
#  'he likes pears , peaches , and lemons .',
#  'paris is never cold during october , but it is relaxing in january .',
#  'you like lemons , grapes , and bananas .',
#  'she drives that little red truck .',
#  'new jersey is pleasant during fall , and it is usually freezing in winter .',
#  'paris is usually rainy during december , and it is cold in winter .',
#  'california is usually pleasant during september , but it is usually freezing in autumn .',
#  'the pear is our least liked fruit , but the orange is their least liked .',
#  'india is snowy during spring , and it is never busy in january .',
#  'i dislike strawberries , mangoes , and pears .',
#  'california is never cold during march , but it is hot in fall .',
#  'china is sometimes chilly during march , and it is sometimes quiet in june .',
#  'her most loved fruit is the grapefruit , but your most loved is the orange .',
#  'the peach is her favorite fruit , but the apple is my favorite .',
#  'paris is usually beautiful during may , and it is never wonderful in june .',
#  'your least liked fruit is the mango , but our least liked is the grapefruit .',
#  'the banana is their favorite fruit , but the grapefruit is your favorite .',
#  'the grape is their least liked fruit , but the strawberry is our least liked .',
#  'the orange is his least favorite fruit , but the banana is your least favorite .',
#  'india is usually quiet during fall , but it is sometimes pleasant in march .',
#  'your most loved animals are horses .',
#  'i dislike peaches , apples , and strawberries .',
#  'paris is sometimes busy during june , and it is never quiet in fall .',
#  'i like bananas , lemons , and grapes .',
#  'you like apples , grapefruit , and limes .',
#  'you dislike peaches , mangoes , and lemons .',
#  'we like oranges , mangoes , and bananas .',
#  'we dislike grapefruit , mangoes , and grapes .',
#  'new jersey is chilly during march , but it is never nice in december .',
#  'you dislike bananas , mangoes , and limes .',
#  'he dislikes pears , mangoes , and strawberries .',
#  'the united states is sometimes rainy during winter , but it is never mild in april .',
#  'i dislike grapefruit , lemons , and peaches .',
#  'paris is usually nice during june , and it is sometimes quiet in autumn .',
#  'you dislike oranges , apples , and grapefruit .',
#  'new jersey is sometimes busy during july , and it is sometimes warm in october .',
#  'california is sometimes chilly during winter , but it is usually rainy in june .',
#  'china is sometimes wet during august , but it is never quiet in october .',
#  'paris is hot during spring , but it is usually snowy in june .',
#  'the grape is your least favorite fruit , but the banana is his least favorite .',
#  'china is never warm during summer , but it is usually quiet in november .',
#  'she dislikes strawberries , pears , and limes .',
#  'his least favorite animal is the mouse .',
#  'he dislikes bananas , mangoes , and apples .',
#  'the lemon is our favorite fruit , but the orange is my favorite .',
#  'france is usually hot during spring , but it is never pleasant in september .',
#  'china is chilly during march , and it is never relaxing in may .',
#  'france is sometimes mild during november , and it is sometimes busy in spring .',
#  'california is usually mild during fall , but it is never chilly in september .',
#  'paris is never wonderful during september , and it is hot in july .',
#  'we dislike peaches , limes , and oranges .',
#  'the apple is your least liked fruit , but the strawberry is their least liked .',
#  'the united states is sometimes wonderful during autumn , but it is usually wet in june .',
#  'he went to the united states last spring .',
#  'france is wet during fall , and it is never relaxing in june .',
#  'i like oranges , grapes , and pears .',
#  'he was driving the little yellow car .',
#  'i dislike limes , apples , and peaches.',
#  'the united states is snowy during march , but it is sometimes quiet in december .',
#  'india is quiet during august , and it is usually mild in january .',
#  'the united states is never freezing during november , but it is sometimes rainy in winter .',
#  'india is relaxing during fall , and it is wonderful in march .',
#  'the strawberry is your favorite fruit , but the peach is our favorite.',
#  'new jersey is sometimes rainy during fall , but it is freezing in spring .',
#  'the banana is your least liked fruit , but the mango is my least liked .',
#  'france is usually pleasant during may , and it is never hot in winter .',
#  'the mango is our least liked fruit , but the banana is his least liked .',
#  'india is usually warm during april , but it is usually busy in august .',
#  'the orange is his favorite fruit , but the strawberry is our favorite .',
#  'you like grapes , limes , and mangoes .',
#  'that horse is your least favorite animal .',
#  'she dislikes bananas , oranges , and grapefruit .',
#  'we dislike oranges , grapefruit , and bananas .',
#  'paris is usually quiet during autumn , but it is usually snowy in march .',
#  'she likes apples , mangoes , and oranges .',
#  'he dislikes the old red automobile .',
#  'dogs are your least favorite animals .',
#  'she was driving the little white car .',
#  'the united states is sometimes busy during spring , and it is usually mild in november .',
#  'california is sometimes freezing during september , and it is never warm in spring .',
#  'china is snowy during august , but it is never beautiful in january .',
#  'our most loved fruit is the orange , but their most loved is the lemon .',
#  'your least liked fruit is the grape , but his least liked is the orange .',
#  'india is sometimes quiet during december , but it is never nice in winter .',
#  'she dislikes oranges , grapes , and lemons .',
#  'new jersey is never busy during november , and it is never cold in march .',
#  'my least favorite fruit is the lime , but her least favorite is the pear .',
#  'the grape is your least favorite fruit .',
#  'france is sometimes freezing during may , and it is never wet in august .',
#  'his favorite animals were horses .',
#  'paris is never snowy during december , and it is never wet in february .',
#  'india is sometimes pleasant during january , but it is never mild in october .',
#  'new jersey is cold during december , but it is never warm in february .',
#  'the lime is our favorite fruit , but the lemon is her favorite.',
#  'he likes peaches , oranges , and lemons .',
#  'the united states is never warm during january , and it is rainy in september .',
#  'the united states is pleasant during june , but it is sometimes warm in summer .',
#  'the grapefruit is their least liked fruit , but the mango is her least liked .',
#  'she is going to china next june .',
#  'he likes strawberries , apples , and grapes .',
#  'china is sometimes busy during july , and it is usually quiet in march .',
#  'we dislike bananas , lemons , and mangoes .',
#  'california is never busy during december , but it is usually hot in fall .',
#  'france is usually relaxing during winter , but it is usually mild in july .',
#  'new jersey is usually hot during autumn , and it is never quiet in winter .',
#  'paris is never nice during september , and it is sometimes cold in march .',
#  'new jersey is sometimes wet during september , but it is usually beautiful in august .',
#  'the united states is sometimes rainy during march , and it is never hot in autumn .',
#  'the elephant is his most loved animal .',
#  'india is usually hot during october , and it is usually wet in june .',
#  'their least favorite fruit is the peach , but your least favorite is the banana .',
#  'paris is sometimes beautiful during september , but it is sometimes wet in march .',
#  'california is hot during october , and it is usually pleasant in march .',
#  'he likes grapes and lemons.',
#  'new jersey is beautiful during march , but it is busy in winter .',
#  'china is never wonderful during november , but it is sometimes quiet in spring .',
#  'the united states is usually freezing during autumn , but it is usually dry in june .',
#  'the peach is my least favorite fruit , but the grape is their least favorite .',
#  'he dislikes apples , limes , and pears .',
#  'paris is usually cold during summer , and it is sometimes dry in winter .',
#  'paris is hot during may , and it is never pleasant in august .',
#  'his favorite fruit is the grapefruit , but my favorite is the mango.',
#  'the united states is sometimes pleasant during july , but it is sometimes dry in june .',
#  'the grape is our least liked fruit , but the strawberry is her least liked .',
#  'california is never quiet during september , and it is sometimes mild in december .',
#  'the lime is her least favorite fruit , but the peach is your least favorite .',
#  'the united states is never mild during august , but it is never beautiful in winter .',
#  'new jersey is never freezing during february , and it is usually cold in summer .',
#  'the strawberry is their least liked fruit , but the apple is our least liked.',
#  'india is never beautiful during spring , but it is usually freezing in february .',
#  'the grape is our least liked fruit , but the grapefruit is his least liked .',
#  'i plan to visit france in spring .',
#  'new jersey is never nice during february , but it is chilly in spring .',
#  'she saw that new yellow truck .',
#  'she likes grapes , apples , and grapefruit.',
#  'that cat was your favorite animal .',
#  'the united states is sometimes snowy during march , and it is usually cold in october .',
#  'the united states is sometimes beautiful during april , but it is usually busy in october .',
#  'california is beautiful during september , but it is wonderful in august .',
#  'her most loved fruit is the apple , but their most loved is the grape .',
#  'he likes grapes and apples.',
#  'california is chilly during january , but it is never busy in spring .',
#  'she dislikes bananas , grapefruit , and mangoes .',
#  'you dislike bananas , peaches , and limes .',
#  'california is never warm during march , but it is sometimes relaxing in may .',
#  'paris is mild during december , but it is dry in winter .',
#  'our most loved fruit is the grapefruit , but their most loved is the pear .',
#  'france is sometimes chilly during june , but it is sometimes wet in november .',
#  'paris is sometimes quiet during may , but it is usually dry in january .',
#  'our most loved fruit is the strawberry , but his most loved is the mango.',
#  'our least liked fruit is the grape , but her least liked is the grapefruit .',
#  'their favorite fruit is the apple , but his favorite is the strawberry .',
#  'my least liked fruit is the pear , but her least liked is the mango .',
#  'we like peaches , grapes , and apples .',
#  'france is never wet during september , but it is usually mild in december .',
#  'the lemon is your least liked fruit , but the peach is his least liked .',
#  'new jersey is cold during february , and it is never hot in winter .',
#  'the united states is never freezing during november , but it is sometimes cold in fall .',
#  'france is usually quiet during august , but it is usually chilly in february .',
#  'california is pleasant during january , but it is usually chilly in april .',
#  'they like grapes , peaches , and strawberries .',
#  'china is never wonderful during april , but it is sometimes wet in march .',
#  'i dislike peaches , mangoes , and oranges .',
#  'your favorite fruit is the strawberry , but our favorite is the banana.',
#  'she likes bananas , strawberries , and grapes .',
#  'his least favorite fruit is the grapefruit , but our least favorite is the peach.',
#  'india is nice during december , but it is sometimes warm in january .',
#  'the orange is their least favorite fruit , but the lime is his least favorite .',
#  'the mango is their most loved fruit , but the pear is my most loved .',
#  'india is never wet during august , but it is sometimes hot in winter .',
#  'new jersey is sometimes hot during winter , and it is never nice in fall .',
#  'he is driving the old black car .',
#  'paris is never cold during january , but it is sometimes snowy in november .',
#  'the grape is my favorite fruit , but the peach is his favorite.',
#  'france is snowy during july , but it is beautiful in june .',
#  'paris is never busy during february , and it is never cold in august .',
#  'california is sometimes relaxing during april , but it is sometimes dry in autumn .',
#  'india is relaxing during february , but it is never rainy in june .',
#  'california is usually chilly during may , and it is sometimes dry in july .',
#  'china is never busy during september , but it is rainy in october .',
#  'new jersey is busy during august , and it is relaxing in december .',
#  'i think it is difficult to translate between spanish and portuguese .',
#  'india is busy during april , but it is sometimes dry in fall .',
#  'france is busy during august , and it is nice in february .',
#  'their favorite fruit is the orange , but my favorite is the grapefruit .',
#  'paris is sometimes rainy during winter , but it is chilly in fall .',
#  'india is usually beautiful during july , but it is cold in autumn .',
#  'the pear is your least liked fruit , but the lemon is my least liked .',
#  'her least favorite fruit is the banana , but your least favorite is the grapefruit .',
#  'france is sometimes quiet during november , but it is warm in february .',
#  'new jersey is rainy during summer , but it is sometimes mild in february .',
#  'new jersey is never rainy during autumn , but it is never pleasant in march .',
#  'france is never snowy during october , and it is sometimes wet in april .',
#  'the lime is her least liked fruit , but the grape is our least liked .',
#  'she is driving the rusty blue truck .',
#  'paris is usually beautiful during july , and it is sometimes chilly in may .',
#  'france is never busy during autumn , but it is quiet in january .',
#  'india is never quiet during january , but it is sometimes freezing in december .',
#  'new jersey is sometimes wet during october , but it is mild in summer .',
#  'china is never chilly during february , and it is sometimes wonderful in november .',
#  'the united states is quiet during fall , but it is usually freezing in may .',
#  'california is never busy during fall , but it is sometimes wet in april .',
#  'they dislike pears , grapes , and bananas .',
#  'he liked a big green automobile .',
#  'new jersey is sometimes quiet during winter , and it is never hot in spring .',
#  'new jersey is sometimes beautiful during march , but it is usually wonderful in summer .',
#  'they dislike mangoes , grapes , and strawberries.',
#  'the united states is never beautiful during november , and it is never quiet in july .',
#  'i think translating between spanish and portuguese is fun .',
#  'the banana is our favorite fruit , but the lemon is your favorite .',
#  'paris is sometimes snowy during january , and it is usually hot in april .',
#  'their least favorite fruit is the mango , but her least favorite is the peach .',
#  'new jersey is never cold during september , and it is sometimes quiet in july .',
#  'china is usually wonderful during october , and it is usually dry in june .',
#  'she saw that rusty white car .',
#  'france is wonderful during december , but it is sometimes freezing in winter .',
#  'the united states is relaxing during november , and it is sometimes snowy in winter .',
#  'your least favorite fruit is the banana , but our least favorite is the strawberry .',
#  'she saw the new green truck .',
#  'the strawberry is your most loved fruit , but the lemon is his most loved.',
#  'new jersey is never busy during october , but it is cold in september .',
#  'they like mangoes , limes , and grapes.',
#  'the pear is her least liked fruit , but the orange is their least liked .',
#  'china is usually freezing during february , but it is never snowy in summer .',
#  'your most loved fruit is the peach , but my most loved is the mango .',
#  'he likes that big blue truck .',
#  'new jersey is sometimes relaxing during february , but it is never wet in october .',
#  'new jersey is snowy during march , but it is sometimes wonderful in november .',
#  'india is usually quiet during june , but it is never snowy in december .',
#  'the united states is cold during july , but it is sometimes rainy in may .',
#  'she is driving the little white truck .',
#  'my most loved animal was that bird .',
#  'my least liked fruit is the grapefruit , but our least liked is the orange .',
#  'paris is busy during may , and it is usually rainy in november .',
#  'the grape is my favorite fruit , but the lime is our favorite.',
#  'paris is dry during march , and it is never quiet in august .',
#  'china is relaxing during january , but it is sometimes beautiful in spring .',
#  'india is pleasant during winter , but it is usually quiet in july .',
#  'paris is usually quiet during march , but it is never wonderful in autumn .',
#  'california is usually warm during june , and it is usually pleasant in july .',
#  'paris is sometimes wet during may , and it is never pleasant in spring .',
#  'the lemon is your most loved fruit , but the peach is his most loved .',
#  'he likes strawberries , pears , and oranges .',
#  'the orange is your least liked fruit , but the grapefruit is their least liked .',
#  'his favorite fruit is the grape , but our favorite is the lemon.',
#  'she dislikes lemons , mangoes , and bananas .',
#  'india is never wet during fall , but it is sometimes warm in january .',
#  'paris is sometimes freezing during august , and it is never wet in spring .',
#  'the united states is wonderful during march , but it is never snowy in january .',
#  'the lime is her least liked fruit , but the strawberry is my least liked .',
#  'she drives that big blue automobile .',
#  'i like limes , apples , and mangoes.',
#  'india is pleasant during october , and it is never nice in summer .',
#  'france is rainy during january , but it is never wonderful in fall .',
#  'france is never rainy during may , but it is nice in october .',
#  'she drives the big blue automobile .',
#  'france is pleasant during july , but it is usually dry in december .',
#  'they dislike pears , mangoes , and grapes .',
#  'india is usually wonderful during spring , but it is usually dry in august .',
#  'he is driving a big green truck .',
#  'paris is sometimes cold during march , but it is usually snowy in autumn .',
#  'your favorite fruit is the grape , but their favorite is the grapefruit.',
#  'the orange is my most loved fruit , but the grapefruit is their most loved .',
#  'india is never snowy during november , and it is usually busy in december .',
#  'california is usually wonderful during november , but it is sometimes cold in may .',
#  'india is beautiful during november , and it is usually freezing in autumn .',
#  'the orange is their favorite fruit , but the mango is his favorite .',
#  'you dislike mangoes , lemons , and grapes.',
#  'california is never chilly during august , and it is usually nice in autumn .',
#  'where is the united states ?',
#  'new jersey is dry during spring , and it is never relaxing in march .',
#  'paris is never relaxing during june , but it is sometimes nice in august .',
#  'china is usually nice during autumn , but it is usually warm in october .',
#  'the dog is her favorite animal .',
#  'paris is sometimes freezing during spring , and it is warm in fall .',
#  'california is sometimes rainy during september , but it is wonderful in may .',
#  'they dislike lemons , apples , and grapefruit .',
#  'the united states is usually pleasant during may , and it is rainy in summer .',
#  'the united states is relaxing during spring , and it is nice in september .',
#  'the banana is their least liked fruit , but the peach is my least liked .',
#  'the united states is usually rainy during spring , but it is sometimes beautiful in summer .',
#  'china is usually hot during autumn , and it is sometimes pleasant in fall .',
#  'new jersey is usually relaxing during november , and it is usually mild in october .',
#  'they dislike bananas , mangoes , and limes .',
#  'she saw the new white truck .',
#  'the orange is their least liked fruit , but the strawberry is his least liked .',
#  'he likes bananas , grapes , and apples .',
#  'she disliked a little blue truck .',
#  'she dislikes strawberries , apples , and mangoes .',
#  'she dislikes lemons , oranges , and mangoes .',
#  'their most loved fruit is the grapefruit , but your most loved is the grape .',
#  'india is usually cold during spring , and it is usually dry in august .',
#  'she likes apples , grapes , and bananas .',
#  'china is snowy during fall , but it is cold in september .',
#  'india is sometimes mild during autumn , and it is usually wet in september .',
#  'china is sometimes snowy during december , and it is chilly in november .',
#  'why are they going to new jersey ?',
#  'france is usually chilly during august , but it is never quiet in june .',
#  'the lemon is his most loved fruit , but the lime is your most loved .',
#  'the united states is nice during december , and it is usually rainy in autumn .',
#  'france is never busy during december , and it is never warm in summer .',
#  'france is sometimes snowy during summer , and it is sometimes relaxing in november .',
#  'paris is never wet during fall , and it is sometimes nice in summer .',
#  'california is usually dry during february , and it is sometimes chilly in autumn .',
#  'paris is wonderful during may , and it is dry in spring .',
#  'china is nice during fall , but it is never dry in september .',
#  'china is sometimes wonderful during winter , and it is relaxing in october .',
#  'she likes pears , grapes , and apples .',
#  'california is pleasant during summer , and it is usually nice in january .',
#  'france is quiet during february , but it is sometimes beautiful in september .',
#  'he likes pears , strawberries , and mangoes .',
#  'he drives the rusty white automobile .',
#  'india is sometimes mild during august , and it is usually snowy in april .',
#  'india is usually hot during december , but it is sometimes wonderful in february .',
#  'the mango is my least liked fruit , but the pear is his least liked .',
#  'france is cold during september , but it is hot in july .',
#  'new jersey is warm during october , but it is never hot in autumn .',
#  'china is never relaxing during october , but it is usually mild in july .',
#  'india is usually warm during november , and it is nice in june .',
#  'france is usually snowy during autumn , but it is never chilly in summer .',
#  'our least favorite fruit is the strawberry , but their least favorite is the banana.',
#  'she might go to paris next april .',
#  'she drives that rusty yellow truck .',
#  'china is relaxing during summer , and it is never quiet in february .',
#  'paris is pleasant during january , and it is sometimes cold in spring .',
#  'she dislikes limes , strawberries , and grapefruit.',
#  'california is never mild during october , and it is rainy in february .',
#  'china is never mild during spring , and it is wet in winter .',
#  'the mango is her least liked fruit , but the orange is his least liked .',
#  'paris is sometimes hot during summer , but it is never mild in january .',
#  'he dislikes mangoes , strawberries , and grapes .',
#  'their least favorite fruit is the grapefruit , but our least favorite is the pear .',
#  'california is never snowy during april , and it is usually busy in july .',
#  'the united states is cold during july , but it is sometimes pleasant in spring .',
#  'china is wet during july , and it is quiet in october .',
#  'paris is beautiful during winter , but it is never busy in november .',
#  'the united states is sometimes wonderful during spring , and it is never quiet in october .',
#  'the united states is never rainy during february , but it is pleasant in spring .',
#  'california is never rainy during july , but it is sometimes beautiful in february .',
#  'he dislikes grapefruit , strawberries , and grapes .',
#  'paris is sometimes hot during winter , and it is warm in february .',
#  'he likes limes , mangoes , and bananas .',
#  'the mango is our least liked fruit , but the apple is your least liked .',
#  'california is usually hot during august , and it is sometimes pleasant in july .',
#  'the lemon is her favorite fruit , but the grape is my favorite .',
#  'paris is usually rainy during may , but it is never mild in december .',
#  'they like oranges , bananas , and apples .',
#  'france is sometimes busy during july , and it is rainy in may .',
#  'the lime is his least favorite fruit , but the peach is my least favorite .',
#  'her least liked fruit is the mango , but their least liked is the apple .',
#  'paris is usually wet during june , and it is sometimes rainy in march .',
#  'she drives that new red truck .',
#  'the united states is usually snowy during spring , but it is never chilly in april .',
#  'china is usually wonderful during may , but it is rainy in january .',
#  'his least favorite fruit is the grapefruit , but their least favorite is the mango.',
#  'the apple is your least favorite fruit , but the lime is our least favorite .',
#  'the orange is her least favorite fruit , but the banana is our least favorite .',
#  'france is sometimes dry during summer , but it is snowy in autumn .',
#  'he likes oranges , apples , and lemons .',
#  'california is sometimes cold during december , but it is never hot in july .',
#  'our least favorite fruit is the grape , but their least favorite is the lemon .',
#  'india is sometimes quiet during summer , but it is wet in august .',
#  'china is never warm during fall , and it is never snowy in winter .',
#  'she dislikes limes , strawberries , and lemons.',
#  'he likes mangoes , grapes , and pears .',
#  'we plan to visit new jersey next october .',
#  'the united states is sometimes warm during fall , but it is usually chilly in winter .',
#  'india is never nice during september , but it is sometimes hot in autumn .',
#  'the grape is their least liked fruit , but the pear is her least liked .',
#  'she likes peaches , strawberries , and limes .',
#  'paris is usually freezing during december , but it is usually quiet in fall .',
#  'they dislike limes , grapefruit , and bananas.',
#  'i like bananas , mangoes , and grapefruit .',
#  'this mouse was my most feared animal .',
#  'the united states is usually rainy during winter , but it is never beautiful in june .',
#  'she drove a big white car .',
#  'the mango is their least liked fruit , but the strawberry is my least liked .',
#  'california is never quiet during september , and it is busy in fall .',
#  'she liked that rusty black automobile .',
#  'his most loved fruit is the lime , but her most loved is the lemon .',
#  'the grapefruit is your least liked fruit , but the lemon is his least liked .',
#  'she was driving that shiny blue truck .',
#  'paris is never freezing during july , but it is warm in fall .',
#  'california is sometimes cold during autumn , but it is nice in june .',
#  'california is sometimes warm during february , and it is usually pleasant in january .',
#  'paris is usually busy during june , and it is usually hot in april .',
#  'the united states is sometimes nice during july , and it is sometimes busy in fall .',
#  'china is cold during december , and it is never warm in fall .',
#  'india is never dry during spring , but it is usually pleasant in may .',
#  'the strawberry is our least liked fruit , but the peach is your least liked.',
#  'the lemon is my least favorite fruit , but the grapefruit is your least favorite .',
#  'california is sometimes freezing during september , and it is never dry in summer .',
#  'the mango is his least favorite fruit , but the peach is our least favorite .',
#  'the united states is sometimes hot during july , but it is relaxing in june .',
#  'new jersey is sometimes beautiful during fall , and it is usually freezing in october .',
#  'she likes mangoes , limes , and grapefruit .',
#  'the united states is mild during january , and it is rainy in spring .',
#  'we like pears , oranges , and apples .',
#  'they dislike strawberries , limes , and mangoes .',
#  'the pear is your least favorite fruit , but the lime is their least favorite .',
#  'paris is usually hot during may , but it is sometimes mild in april .',
#  'she drives that new yellow truck .',
#  'he dislikes strawberries , limes , and grapefruit .',
#  'california is sometimes warm during april , but it is usually quiet in may .',
#  'china is usually busy during october , and it is never chilly in july .',
#  'they plan to visit the united states in winter .',
#  'he dislikes grapes , pears , and mangoes.',
#  'he liked the new white car .',
#  'new jersey is never pleasant during august , and it is never relaxing in february .',
#  'china is never cold during summer , and it is usually nice in august .',
#  'she likes strawberries , oranges , and lemons .',
#  'her most loved fruit is the strawberry , but his most loved is the grapefruit .',
#  'she drove a little green truck .',
#  'india is snowy during fall , but it is sometimes rainy in june .',
#  'they plan to visit china in july .',
#  'california is sometimes mild during summer , and it is sometimes warm in february .',
#  'paris is rainy during august , and it is wet in july .',
#  'the united states is sometimes dry during march , and it is never pleasant in winter .',
#  'he likes peaches , lemons , and pears .',
#  'new jersey is never rainy during winter , and it is beautiful in february .',
#  'paris is never beautiful during october , but it is freezing in autumn .',
#  'she dislikes bananas , pears , and limes .',
#  'your favorite fruit is the grapefruit , but my favorite is the apple .',
#  'our most loved fruit is the peach , but their most loved is the mango .',
#  'new jersey is sometimes hot during october , but it is busy in august .',
#  'new jersey is usually dry during march , but it is never cold in july .',
#  'california is usually wonderful during july , but it is cold in winter .',
#  'china is usually relaxing during june , but it is never quiet in summer .',
#  'new jersey is nice during winter , but it is snowy in january .',
#  'france is freezing during january , and it is usually rainy in february .',
#  'the grape is our least favorite fruit , but the pear is my least favorite .',
#  'france is usually warm during june , but it is never chilly in autumn .',
#  'his least favorite fruit is the grapefruit , but their least favorite is the orange.',
#  'new jersey is sometimes rainy during july , and it is never snowy in winter .',
#  'our least favorite fruit is the mango , but their least favorite is the lime .',
#  'new jersey is mild during may , and it is never wet in april .',
#  'france is usually snowy during february , and it is sometimes cold in august .',
#  'india is sometimes chilly during november , but it is sometimes nice in spring .',
#  'their least favorite fruit is the orange , but her least favorite is the peach .',
#  'new jersey is hot during fall , but it is usually dry in november .',
#  'she dislikes bananas , strawberries , and limes .',
#  'his most loved fruit is the lime .',
#  'your least liked fruit is the banana , but their least liked is the grapefruit .',
#  'paris is usually hot during march , and it is never mild in october .',
#  'india is freezing during october , and it is beautiful in spring .',
#  'he likes strawberries , grapes , and mangoes .',
#  'their least liked fruit is the grape , but his least liked is the apple .',
#  'the united states is sometimes dry during february , but it is usually beautiful in november .',
#  'new jersey is beautiful during february , but it is usually wet in fall .',
#  'china is usually beautiful during april , and it is never busy in may .',
#  'new jersey is sometimes warm during winter , but it is sometimes beautiful in october .',
#  'china is never nice during december , but it is usually warm in winter .',
#  'france is chilly during october , and it is never freezing in january .',
#  'india is never chilly during fall , and it is never beautiful in november .',
#  'france is usually wet during september , and it is mild in fall .',
#  'california is never snowy during summer , but it is chilly in february .',
#  'china is usually snowy during september , and it is sometimes nice in summer .',
#  'their least liked fruit is the strawberry , but your least liked is the pear.',
#  'he dislikes peaches , lemons , and strawberries .',
#  'she likes limes , bananas , and grapefruit .',
#  'the strawberry is his most loved fruit , but the pear is their most loved .',
#  'she saw the rusty blue car .',
#  'the grape is my least liked fruit , but the grapefruit is her least liked.',
#  'california is never busy during spring , but it is sometimes nice in october .',
#  'he is driving a little white car .',
#  'she likes apples , mangoes , and bananas .',
#  'paris is sometimes cold during april , but it is sometimes snowy in fall .',
#  'she likes mangoes , oranges , and peaches .',
#  'india is never hot during february , but it is sometimes relaxing in march .',
#  'california is never beautiful during april , and it is never relaxing in summer .',
#  'he was driving the new green automobile .',
#  'new jersey is busy during august , and it is sometimes relaxing in spring .',
#  'the pear is your least liked fruit , but the peach is our least liked .',
#  'china is usually nice during december , but it is never wonderful in may .',
#  'new jersey is sometimes mild during august , but it is beautiful in spring .',
#  'my least favorite animal was this shark .',
#  'new jersey is never snowy during september , but it is hot in may .',
#  'new jersey is never quiet during july , and it is wet in august .',
#  'france is usually quiet during august , and it is wet in january .',
#  'the mango is our favorite fruit , but the lemon is her favorite .',
#  'france is usually freezing during april , and it is sometimes chilly in summer .',
#  'paris is usually busy during autumn , and it is cold in july .',
#  'he disliked the big red automobile .',
#  'she likes peaches , grapes , and oranges .',
#  'paris is sometimes rainy during winter , but it is never hot in july .',
#  'new jersey is pleasant during autumn , and it is never cold in december .',
#  'their favorite fruit is the lemon , but our favorite is the orange .',
#  'he likes apples , bananas , and oranges .',
#  'he likes pears , strawberries , and peaches .',
#  'paris is nice during december , but it is usually pleasant in february .',
#  'the lime is their least liked fruit , but the grape is our least liked.',
#  'new jersey is rainy during june , but it is never quiet in february .',
#  'she likes that rusty yellow automobile .',
#  'the grape is your least favorite fruit , but the banana is my least favorite .',
#  'new jersey is wet during july , but it is wonderful in april .',
#  'california is never rainy during january , but it is quiet in winter .',
#  'your favorite fruit is the mango , but their favorite is the orange .',
#  'the lemon is your most loved fruit , but the strawberry is his most loved .',
#  'china is never freezing during winter , and it is sometimes relaxing in july .',
#  'she likes pears , lemons , and strawberries .',
#  'the banana is our least favorite fruit , but the lemon is her least favorite .',
#  'new jersey is dry during july , and it is never snowy in january .',
#  'they like lemons , apples , and grapefruit .',
#  'he likes apples , pears , and limes .',
#  'his least favorite fruit is the pear , but our least favorite is the banana .',
#  'france is usually freezing during february , and it is never chilly in spring .',
#  'new jersey is sometimes wonderful during november , but it is usually relaxing in spring .',
#  'the banana is my most loved fruit , but the apple is his most loved .',
#  'the lime is our favorite fruit , but the banana is my favorite.',
#  'india is sometimes nice during january , but it is never cold in march .',
#  'india is usually wonderful during spring , and it is sometimes relaxing in autumn .',
#  'paris is usually pleasant during july , but it is cold in october .',
#  'paris is beautiful during fall , and it is hot in january .',
#  'new jersey is beautiful during april , and it is nice in november .',
#  'my favorite fruit is the orange , but our favorite is the lemon .',
#  'her least favorite fruit is the apple , but your least favorite is the lemon .',
#  'new jersey is usually snowy during autumn , and it is usually dry in july .',
#  'he likes limes , oranges , and strawberries .',
#  'the grape is her favorite fruit , but the peach is their favorite.',
#  'she liked that old red automobile .',
#  'china is relaxing during july , but it is usually freezing in autumn .',
#  'she dislikes grapefruit , peaches , and lemons .',
#  'france is sometimes cold during winter , but it is never snowy in summer .',
# ...
#  'he dislikes pears and oranges .',
#  'china is usually mild during fall , but it is never hot in april .',
#  'new jersey is wet during autumn , and it is freezing in fall .',
#  'their favorite fruit is the pear , but my favorite is the orange .',
#  'india is rainy during june , but it is sometimes freezing in september .',
#  'india is usually warm during december , and it is beautiful in april .',
#  'he dislikes grapefruit , grapes , and pears .',
#  'new jersey is never quiet during april , but it is chilly in summer .',
#  'france is quiet during spring , and it is never wet in july .',
#  'india is sometimes freezing during november , but it is never pleasant in march .',
#  'she liked a rusty black truck .',
#  'paris is never hot during august , and it is usually quiet in february .',
#  'he dislikes apples and strawberries .',
#  'the united states is wonderful during april , and it is chilly in january .',
#  'new jersey is sometimes quiet during october , but it is beautiful in summer .',
#  'the united states is usually busy during february , and it is never quiet in june .',
#  'she dislikes bananas , limes , and pears .',
#  'china is sometimes quiet during winter , and it is never chilly in spring .',
#  'the monkey is my most loved animal .',
#  'the grapefruit is her least favorite fruit , but the pear is our least favorite .',
#  'he dislikes mangoes , pears , and oranges .',
#  'the peach is my least favorite fruit , but the lemon is your least favorite .',
#  'india is sometimes hot during september , but it is usually relaxing in july .',
#  'china is sometimes freezing during fall , and it is hot in spring .',
#  'california is nice during may , but it is freezing in july .',
#  'california is usually snowy during summer , but it is rainy in june .',
#  'new jersey is sometimes wonderful during february , and it is usually warm in november .',
#  'my favorite fruit is the grape , but their favorite is the strawberry.',
#  'they dislike grapefruit and mangoes .',
#  'he dislikes grapes , strawberries , and lemons.',
#  'she likes pears , oranges , and grapes .',
#  'china is dry during autumn , and it is sometimes beautiful in august .',
#  'india is usually relaxing during may , and it is sometimes wonderful in february .',
#  'the united states is never snowy during july , and it is mild in january .',
#  'she disliked that old red automobile .',
#  'the united states is usually warm during august , but it is chilly in december .',
#  'california is usually freezing during july , but it is never warm in january .',
#  'i like bananas , pears , and limes .',
#  'she likes lemons and grapes.',
#  'new jersey is pleasant during fall , and it is nice in october .',
#  'how was the weather in new jersey last winter ?',
#  'your least favorite fruit is the apple , but his least favorite is the lime .',
#  'india is never wonderful during june , but it is beautiful in october .',
#  'i dislike peaches , oranges , and bananas .',
#  'my most loved fruit is the lemon , but their most loved is the grape .',
#  'india is sometimes pleasant during winter , but it is sometimes busy in spring .',
#  'his most loved animal was this lion .',
#  'the strawberry is our least liked fruit , but the lemon is their least liked.',
#  'the apple is her most loved fruit , but the lime is their most loved .',
#  'she disliked a shiny red automobile .',
#  'china is rainy during january , and it is sometimes pleasant in april .',
#  'the peach is her least favorite fruit , but the orange is their least favorite .',
#  'the united states is dry during september , but it is never wet in march .',
#  'he plans to visit france in summer .',
#  'he dislikes grapefruit and strawberries .',
#  'india is never cold during april , but it is never nice in october .',
#  'my most loved animal is this monkey .',
#  'her favorite fruit is the orange , but their favorite is the mango .',
#  'california is usually cold during april , but it is dry in october .',
#  'she drove that old blue truck .',
#  'this bear was my most feared animal .',
#  'california is usually rainy during april , and it is usually mild in summer .',
#  'china is snowy during april , and it is cold in spring .',
#  'china is never cold during october , but it is sometimes rainy in winter .',
#  'paris is rainy during december , and it is usually pleasant in july .',
#  'california is never pleasant during january , but it is never hot in december .',
#  'paris is sometimes pleasant during august , and it is usually busy in october .',
#  'he is driving a old black truck .',
#  'the grapefruit is our least favorite fruit , but the lime is your least favorite .',
#  'he dislikes grapefruit , grapes , and bananas .',
#  'france is wonderful during july , but it is usually rainy in june .',
#  'our least favorite fruit is the grape , but my least favorite is the grapefruit .',
#  'paris is usually freezing during autumn , but it is mild in march .',
#  'new jersey is usually pleasant during february , and it is sometimes beautiful in june .',
#  'i dislike apples , lemons , and grapes .',
#  'the lemon is your most loved fruit , but the peach is my most loved .',
#  'he likes a little blue car .',
#  'india is never wonderful during summer , and it is usually pleasant in december .',
#  'china is nice during july , but it is usually chilly in october .',
#  'new jersey is usually chilly during august , but it is sometimes freezing in summer .',
#  'china is hot during fall , and it is sometimes warm in november .',
#  'new jersey is usually quiet during fall , but it is usually warm in june .',
#  'china is snowy during august , but it is usually freezing in february .',
#  'china is never busy during october , but it is never warm in fall .',
#  'china is usually cold during summer , but it is usually freezing in january .',
#  'the strawberry is our most loved fruit , but the lime is your most loved.',
#  'the lime is our least liked fruit , but the apple is her least liked.',
#  'paris is beautiful during fall , and it is rainy in april .',
#  'the united states is never dry during december , but it is sometimes busy in autumn .',
#  'your favorite fruit is the grape , but their favorite is the strawberry.',
#  'new jersey is usually warm during june , but it is sometimes freezing in winter .',
#  'france is usually rainy during winter , but it is usually wet in september .',
#  'she likes lemons and bananas.',
#  'california is sometimes dry during may , and it is usually freezing in february .',
#  'paris is sometimes busy during spring , but it is sometimes wet in february .',
#  'new jersey is chilly during july , but it is usually quiet in june .',
#  'california is sometimes mild during spring , but it is sometimes quiet in november .',
#  'paris is sometimes quiet during december , and it is usually freezing in autumn .',
#  'the pear is their most loved fruit , but the peach is your most loved .',
#  'she likes that new red car .',
#  'new jersey is never mild during winter , and it is freezing in october .',
#  'she dislikes mangoes and pears.',
#  'she likes limes , oranges , and grapefruit .',
#  'france is usually mild during september , but it is sometimes hot in november .',
#  'paris is usually warm during may , and it is never hot in october .',
#  'the united states is never cold during december , but it is never quiet in summer .',
#  'we dislike mangoes , bananas , and peaches.',
#  'california is sometimes mild during fall , and it is sometimes freezing in december .',
#  'her most loved animals are sharks .',
#  'the grapefruit is our least liked fruit , but the orange is their least liked .',
#  'you dislike apples , lemons , and bananas .',
#  'his most loved fruit is the grapefruit , but your most loved is the peach.',
#  'india is cold during august , and it is sometimes nice in september .',
#  'our least liked fruit is the lemon , but my least liked is the mango .',
#  'i plan to visit the united states next may .',
#  'the orange is their favorite fruit , but the grape is his favorite .',
#  'your most loved fruit is the grape , but our most loved is the banana .',
#  'this cat is my favorite animal .',
#  'she dislikes the shiny black automobile .',
#  'they are going to paris next summer .',
#  'paris is sometimes busy during autumn , but it is never nice in january .',
#  'his least favorite fruit is the grapefruit , but our least favorite is the apple.',
#  'he likes that little black automobile .',
#  'china is never freezing during fall , but it is sometimes quiet in june .',
#  'france is sometimes relaxing during january , but it is never beautiful in autumn .',
#  'new jersey is usually mild during march , but it is never wonderful in autumn .',
#  'he dislikes strawberries , bananas , and oranges .',
#  'india is beautiful during fall , but it is never busy in october .',
#  'she saw that rusty blue truck .',
#  'china is sometimes snowy during autumn , but it is wonderful in july .',
#  'the banana is their favorite fruit , but the pear is our favorite .',
#  'the united states is snowy during february , and it is usually nice in december .',
#  'new jersey is never wet during november , and it is sometimes beautiful in september .',
#  'france is never cold during august , but it is usually rainy in may .',
#  'the united states is usually wet during july , but it is sometimes mild in autumn .',
#  'new jersey is sometimes beautiful during january , but it is usually hot in october .',
#  'paris is sometimes pleasant during summer , and it is usually relaxing in january .',
#  'india is never quiet during october , and it is sometimes pleasant in november .',
#  'india is mild during fall , but it is sometimes warm in september .',
#  'she likes grapefruit , pears , and peaches .',
#  'we like peaches , oranges , and apples .',
#  'india is sometimes snowy during october , but it is usually freezing in february .',
#  'her most feared animal was that rabbit .',
#  'he likes mangoes , peaches , and grapefruit .',
#  'she dislikes apples , pears , and grapes .',
#  'the strawberry is his favorite fruit , but the apple is her favorite .',
#  'the mango is my favorite fruit , but the lemon is your favorite .',
#  'i like grapes , peaches , and oranges .',
#  'california is never rainy during december , but it is busy in april .',
#  'that rabbit was her most feared animal .',
#  'we dislike lemons , mangoes , and oranges .',
#  'paris is sometimes busy during may , and it is usually nice in july .',
#  'california is sometimes freezing during fall , but it is never hot in summer .',
#  'france is usually nice during april , and it is chilly in november .',
#  'paris is usually cold during february , and it is usually rainy in fall .',
#  'the lemon is her least favorite fruit , but the mango is our least favorite .',
#  'she is driving that big blue automobile .',
#  'new jersey is snowy during june , and it is never beautiful in april .',
#  'you dislike lemons , apples , and bananas .',
#  'france is freezing during march , but it is sometimes cold in october .',
#  'new jersey is sometimes hot during november , and it is never rainy in june .',
#  'the mango is their least favorite fruit , but the pear is my least favorite .',
#  'new jersey is usually pleasant during july , but it is never wet in summer .',
#  'france is sometimes relaxing during june , but it is usually mild in winter .',
#  'he likes grapefruit , apples , and peaches .',
#  'china is never hot during fall , and it is dry in spring .',
#  'the apple is your least favorite fruit , but the orange is my least favorite .',
#  'he dislikes strawberries , apples , and lemons .',
#  'the bear is my most feared animal .',
#  "it's difficult to translate spanish to chinese .",
#  'we dislike pears , oranges , and strawberries .',
#  'india is pleasant during september , but it is sometimes chilly in april .',
#  'i dislike oranges , strawberries , and apples .',
#  'new jersey is wonderful during fall , but it is sometimes mild in august .',
#  'france is sometimes mild during september , and it is usually rainy in november .',
#  'the mango is my least favorite fruit , but the grape is your least favorite .',
#  'she dislikes mangoes , bananas , and peaches .',
#  'california is nice during may , but it is usually wonderful in february .',
#  'india is sometimes rainy during july , and it is usually relaxing in january .',
#  'the orange is your favorite fruit , but the banana is her favorite .',
#  'paris is sometimes beautiful during april , but it is sometimes chilly in february .',
#  'we like oranges , limes , and peaches .',
#  'new jersey is dry during autumn , and it is never nice in february .',
#  'california is never quiet during winter , and it is wet in spring .',
#  'i like grapefruit and strawberries .',
#  'your most loved fruit is the peach , but his most loved is the strawberry .',
#  'france is never nice during july , and it is freezing in january .',
#  'i like grapefruit , pears , and limes .',
#  'she likes grapes , oranges , and pears.',
#  'california is quiet during summer , but it is never rainy in september .',
#  'he likes limes , grapefruit , and lemons .',
#  'the united states is quiet during march , but it is usually beautiful in fall .',
#  'paris is sometimes freezing during fall , but it is usually rainy in spring .',
#  'their least liked fruit is the grapefruit , but her least liked is the strawberry .',
#  'new jersey is quiet during january , but it is sometimes nice in fall .',
#  'california is usually nice during autumn , and it is usually busy in july .',
#  'china is sometimes wet during may , but it is usually dry in autumn .',
#  'mangoes are my favorite fruit .',
#  'they like strawberries , grapefruit , and peaches .',
#  'when is she going to the eiffel tower ?',
#  'the strawberry is her least liked fruit , but the peach is our least liked .',
#  'the orange is my most loved fruit , but the lime is our most loved .',
#  'new jersey is rainy during august , and it is never snowy in june .',
#  'california is usually pleasant during june , and it is never busy in february .',
#  'paris is usually chilly during january , and it is relaxing in spring .',
#  'she dislikes bananas , grapefruit , and mangoes .',
#  'new jersey is chilly during march , but it is never hot in june .',
#  'china is sometimes chilly during june , and it is sometimes beautiful in january .',
#  'the united states is never quiet during january , and it is hot in may .',
#  'when did we go to the grocery store ?',
#  'the united states is never dry during february , and it is wet in september .',
#  'california is beautiful during summer , and it is usually rainy in july .',
#  'new jersey is never chilly during winter , but it is sometimes pleasant in summer .',
#  'france is sometimes quiet during spring , but it is never snowy in december .',
#  'that horse is my most loved animal .',
#  'california is never wonderful during september , and it is usually nice in autumn .',
#  'she wanted to go to new jersey last february .',
#  'france is never pleasant during june , but it is sometimes mild in march .',
#  'the banana is his least liked fruit , but the peach is my least liked .',
#  'she dislikes mangoes , strawberries , and apples.',
#  'the orange is his favorite fruit , but the lime is our favorite .',
#  'new jersey is sometimes hot during july , and it is never warm in summer .',
#  'his favorite fruit is the peach , but her favorite is the strawberry .',
#  'the lemon is their least liked fruit , but the lime is your least liked .',
#  'india is usually cold during september , but it is never dry in april .',
#  'california is cold during september , but it is busy in august .',
#  'the united states is never rainy during spring , but it is sometimes wet in september .',
#  'new jersey is dry during autumn , and it is never beautiful in april .',
#  'china is usually quiet during april , and it is never rainy in february .',
#  'china is cold during july , and it is freezing in winter .',
#  'china is usually wet during march , and it is sometimes freezing in september .',
#  'france is usually snowy during december , and it is never busy in spring .',
#  'the grape is our most loved fruit , but the strawberry is his most loved .',
#  ...]

# %% [markdown]
# #Analysis of Dataset
# Let us look at a few examples in the dataset of both language

# %%
for i in range(3):
  print('Sample :',i)
  print(english_sentences[i])
  print(french_sentences[i])
  print('-'*50)
# Out:
# Sample : 0
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# --------------------------------------------------
# Sample : 1
# the united states is usually chilly during july , and it is usually freezing in november .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# --------------------------------------------------
# Sample : 2
# california is usually quiet during march , and it is usually hot in june .
# california est généralement calme en mars , et il est généralement chaud en juin .
# --------------------------------------------------

# %% [markdown]
# #Convert to Vocabulary
# The complexity of the problem is determined by the complexity of the vocabulary. A more complex vocabulary is a more complex problem. Let's look at the complexity of the dataset we'll be working with.

# %%
import collections

# %%
english_words_counter = collections.Counter([word for sentence in english_sentences for word in sentence.split()])
french_words_counter = collections.Counter([word for sentence in french_sentences for word in sentence.split()])

print('English Vocab:',len(english_words_counter))
print('French Vocab:',len(french_words_counter))
# Out:
# English Vocab: 227
# French Vocab: 355

# %% [markdown]
# #Tokenize (IMPLEMENTATION)
# For a neural network to predict on text data, it first has to be turned into data it can understand. Text data like "dog" is a sequence of ASCII character encodings. Since a neural network is a series of multiplication and addition operations, the input data needs to be number(s).
#
# We can turn each character into a number or each word into a number. These are called character and word ids, respectively.
# - Character ids are used for character level models that generate text predictions for each character.
# - A word level model uses word ids that generate text predictions for each word. Word level models tend to learn better, since they are lower in complexity, so we'll use that.
#
# **TO_DO:** Turn each sentence into a sequence of words_ids using Keras's Tokenizer function. Use this function to tokenize english_sentences and french_sentences in the cell below.

# %%
from collections import Counter
def tokenize(x):
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(x)
  return tokenizer

# %%
# Tokenize Sample output
text_sentences = [
    'The quick brown fox jumps over the lazy dog .',
    'By Jove , my quick study of lexicography won a prize .',
    'This is a short sentence .']

text_tokenizer = tokenize(text_sentences)
print(text_tokenizer.word_index)
text_tokenized = text_tokenizer.texts_to_sequences(text_sentences)

for sample_i, (sent, token_sent) in enumerate(zip(text_sentences, text_tokenized)):
  print('Sequence {} in x'.format(sample_i + 1))
  print('  Input:  {}'.format(sent))
  print('  Output: {}'.format(token_sent))
# Out:
# {'the': 1, 'quick': 2, 'a': 3, 'brown': 4, 'fox': 5, 'jumps': 6, 'over': 7, 'lazy': 8, 'dog': 9, 'by': 10, 'jove': 11, 'my': 12, 'study': 13, 'of': 14, 'lexicography': 15, 'won': 16, 'prize': 17, 'this': 18, 'is': 19, 'short': 20, 'sentence': 21}
# Sequence 1 in x
#   Input:  The quick brown fox jumps over the lazy dog .
#   Output: [1, 2, 4, 5, 6, 7, 1, 8, 9]
# Sequence 2 in x
#   Input:  By Jove , my quick study of lexicography won a prize .
#   Output: [10, 11, 12, 2, 13, 14, 15, 16, 3, 17]
# Sequence 3 in x
#   Input:  This is a short sentence .
#   Output: [18, 19, 3, 20, 21]

# %% [markdown]
# #Padding (IMPLEMENTATION)
# When batching the sequence of word ids together, each sequence needs to be the same length. Since sentences are dynamic in length, we can add padding to the end of the sequences to make them the same length.
#
# Make sure all the English sequences have the same length and all the French sequences have the same length by adding padding to the end of each sequence using Keras's pad_sequences function.

# %%
def pad(x, length=None):
  ## TO_DO:
  text_padded = pad_sequences(x, maxlen=length, padding='post')
  return text_padded

# %%
def preprocess(x, y):
    """
    Preprocess x and y
    :param x: Feature List of sentences
    :param y: Label List of sentences
    :return: Tuple of (Preprocessed x, Preprocessed y, x tokenizer, y tokenizer)
    """
    x_tk = tokenize(x)
    preprocess_x = x_tk.texts_to_sequences(x)
    y_tk = tokenize(y)
    preprocess_y = y_tk.texts_to_sequences(y)

    preprocess_x = pad(preprocess_x)
    preprocess_y = pad(preprocess_y)

    # Keras's sparse_categorical_crossentropy function requires the labels to be in 3 dimensions
    #Expanding dimensions
    preprocess_y = preprocess_y.reshape(*preprocess_y.shape, 1)

    return preprocess_x, preprocess_y, x_tk, y_tk

preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer =\
    preprocess(english_sentences, french_sentences)

max_english_sequence_length = preproc_english_sentences.shape[1]
max_french_sequence_length = preproc_french_sentences.shape[1]
english_vocab_size = len(english_tokenizer.word_index)
french_vocab_size = len(french_tokenizer.word_index)


print('Data Preprocessed.')
print("Max English sentence length:", max_english_sequence_length)
print("Max French sentence length:", max_french_sequence_length)
print("English vocabulary size:", english_vocab_size)
print("French vocabulary size:", french_vocab_size)

print("Are all English sequences of the same length?", all(len(seq) == max_english_sequence_length for seq in preproc_english_sentences))
print("Are all French sequences of the same length?", all(len(seq) == max_french_sequence_length for seq in preproc_french_sentences))
# Out:
# Prédictions:   1%|▏         | 127/10000 [14:19<18:33:34,  6.77s/it]
# Data Preprocessed.
# Max English sentence length: 15
# Max French sentence length: 21
# English vocabulary size: 199
# French vocabulary size: 344
# Are all English sequences of the same length? True
# Are all French sequences of the same length? True

# %% [markdown]
# #Create Model

# %% [markdown]
# The neural network will translate the input to words ids, which isn't the final form we want. We want the French translation. The function logits_to_text will bridge the gap between the logits from the neural network to the French translation. You'll be using this function to better understand the output of the neural network.

# %%
def logits_to_text(logits, tokenizer):
  index_to_words = {id: word for word, id in tokenizer.word_index.items()}
  index_to_words[0] = '<PAD>'

  #So basically we are predicting output for a given word and then selecting best answer
  #Then selecting that label we reverse-enumerate the word from id
  return ' '.join([index_to_words[prediction] for prediction in np.argmax(logits, 1)])

# %% [markdown]
# ![Model](https://github.com/tommytracey/AIND-Capstone/raw/8267d4fe72e48c595a0aff46eaf0a805fff0f36d/images/embedding.png)

# %% [markdown]
# #Building Model
# Here we use RNN model combined with GRU nodes for translation.
# In the code section below, we give a simple model example. You can first run this model and play with it. Then you can change the model architecture by following the Exercise 4 to get better results.

# %%
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a RNN model using word embedding on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """

    ## TO_DO: Improve the layers (See Exercise 4)
    model = Sequential()
    model.add(Embedding(english_vocab_size, 256, input_length=input_shape[1], input_shape=input_shape[1:]))
    model.add(GRU(256, return_sequences=True))
    model.add(TimeDistributed(Dense(1024, activation='relu')))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(french_vocab_size, activation='softmax')))

    return model

# %%
# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, preproc_french_sentences.shape[1])
print(f"Shape before reshaping: {tmp_x.shape}")
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2]))
print(f"Shape after reshaping: {tmp_x.shape}")
# Out:
# Shape before reshaping: (137860, 21)
# Shape after reshaping: (137860, 21)

# %% [markdown]
# Finally calling the model function

# %%
# Hyperparameters
learning_rate = 0.005

# %%
simple_rnn_model = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index)+1,
    len(french_tokenizer.word_index)+1)

# %% [markdown]
# The output is a sequence of one-hot encoded arrays. Our data-set contains integer-tokens instead of one-hot encoded arrays. Each one-hot encoded array has large number of elements so it would be extremely wasteful to convert the entire data-set to one-hot encoded arrays. A better way is to use a so-called sparse cross-entropy loss-function, which does the conversion internally from integers to one-hot encoded arrays.

# %%
# Compile model
simple_rnn_model.compile(loss=sparse_categorical_crossentropy,
                         optimizer=Adam(learning_rate),
                         metrics=['accuracy'])

# %%
simple_rnn_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 21, 256)           51200
#
#  gru_10 (GRU)                (None, 21, 256)           394752
#
#  time_distributed_20 (TimeD  (None, 21, 1024)          263168
#  istributed)
#
#  dropout_10 (Dropout)        (None, 21, 1024)          0
#
#  time_distributed_21 (TimeD  (None, 21, 345)           353625
#  istributed)
#
# =================================================================
# Total params: 1062745 (4.05 MB)
# Trainable params: 1062745 (4.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #Training the model
# Here we start to train the model and pass the english text and the max_sequence_length, with vocab size for both english and french text

# %%
history=simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 11s 77ms/step - loss: 1.3475 - accuracy: 0.6844 - val_loss: 0.4694 - val_accuracy: 0.8482
# Epoch 2/10
# 108/108 [==============================] - 7s 64ms/step - loss: 0.3987 - accuracy: 0.8688 - val_loss: 0.2931 - val_accuracy: 0.9018
# Epoch 3/10
# 108/108 [==============================] - 7s 61ms/step - loss: 0.2879 - accuracy: 0.9039 - val_loss: 0.2399 - val_accuracy: 0.9185
# Epoch 4/10
# 108/108 [==============================] - 6s 60ms/step - loss: 0.2434 - accuracy: 0.9176 - val_loss: 0.2153 - val_accuracy: 0.9264
# Epoch 5/10
# 108/108 [==============================] - 6s 58ms/step - loss: 0.2197 - accuracy: 0.9243 - val_loss: 0.2009 - val_accuracy: 0.9306
# Epoch 6/10
# 108/108 [==============================] - 7s 62ms/step - loss: 0.2054 - accuracy: 0.9287 - val_loss: 0.1973 - val_accuracy: 0.9324
# Epoch 7/10
# 108/108 [==============================] - 7s 64ms/step - loss: 0.1942 - accuracy: 0.9321 - val_loss: 0.1904 - val_accuracy: 0.9331
# Epoch 8/10
# 108/108 [==============================] - 7s 61ms/step - loss: 0.1877 - accuracy: 0.9337 - val_loss: 0.1836 - val_accuracy: 0.9358
# Epoch 9/10
# 108/108 [==============================] - 6s 59ms/step - loss: 0.1816 - accuracy: 0.9352 - val_loss: 0.1800 - val_accuracy: 0.9365
# Epoch 10/10
# 108/108 [==============================] - 7s 63ms/step - loss: 0.1807 - accuracy: 0.9356 - val_loss: 0.1876 - val_accuracy: 0.9343

# %% [markdown]
# #Arbitrary Predictions
#
# Try with arbitary examples in the corpus to see the translation

# %%
import re
def final_predictions(text):
  y_id_to_word = {value: key for key, value in french_tokenizer.word_index.items()}
  y_id_to_word[0] = '<PAD>'

  sentence = [english_tokenizer.word_index[word] for word in text.split()]
  sentence = pad_sequences([sentence], maxlen=preproc_french_sentences.shape[-2], padding='post')
  french_translation = logits_to_text(simple_rnn_model.predict(sentence[:1], verbose=0)[0], french_tokenizer)
  return re.split(r"\s*<PAD>", french_translation, 1)[0]

# %%
txt = english_sentences[0].lower()
print('English: ', english_sentences[0])
print('French: ', final_predictions(re.sub(r'[^\w]', ' ', txt)))
# Out:
# English:  new jersey is sometimes quiet during autumn , and it is snowy in april .
# French:  new jersey est parfois calme en l' automne il est neigeux en avril

# %% [markdown]
# # Evaluation
#
# In this section, we provide the example code for you to do the evaluation using BLEU score metrics.

# %%
# useful tokenization
import re
from functools import lru_cache


class BaseTokenizer:
    """A base dummy tokenizer to derive from."""

    def signature(self):
        """
        Returns a signature for the tokenizer.
        :return: signature string
        """
        return "none"

    def __call__(self, line):
        """
        Tokenizes an input line with the tokenizer.
        :param line: a segment to tokenize
        :return: the tokenized line
        """
        return line


class TokenizerRegexp(BaseTokenizer):
    def signature(self):
        return "re"

    def __init__(self):
        self._re = [
            # language-dependent part (assuming Western languages)
            (re.compile(r"([\{-\~\[-\` -\&\(-\+\:-\@\/])"), r" \1 "),
            # tokenize period and comma unless preceded by a digit
            (re.compile(r"([^0-9])([\.,])"), r"\1 \2 "),
            # tokenize period and comma unless followed by a digit
            (re.compile(r"([\.,])([^0-9])"), r" \1 \2"),
            # tokenize dash when preceded by a digit
            (re.compile(r"([0-9])(-)"), r"\1 \2 "),
            # one space only between words
            # NOTE: Doing this in Python (below) is faster
            # (re.compile(r'\s+'), r' '),
        ]

    @lru_cache(maxsize=2**16)
    def __call__(self, line):
        """Common post-processing tokenizer for `13a` and `zh` tokenizers.
        :param line: a segment to tokenize
        :return: the tokenized line
        """
        for (_re, repl) in self._re:
            line = _re.sub(repl, line)

        # no leading or trailing spaces, single space within words
        # return ' '.join(line.split())
        # This line is changed with regards to the original tokenizer (seen above) to return individual words
        return line.split()


class Tokenizer13a(BaseTokenizer):
    def signature(self):
        return "13a"

    def __init__(self):
        self._post_tokenizer = TokenizerRegexp()

    @lru_cache(maxsize=2**16)
    def __call__(self, line):
        """Tokenizes an input line using a relatively minimal tokenization
        that is however equivalent to mteval-v13a, used by WMT.

        :param line: a segment to tokenize
        :return: the tokenized line
        """

        # language-independent part:
        line = line.replace("<skipped>", "")
        line = line.replace("-\n", "")
        line = line.replace("\n", " ")

        if "&" in line:
            line = line.replace("&quot;", '"')
            line = line.replace("&amp;", "&")
            line = line.replace("&lt;", "<")
            line = line.replace("&gt;", ">")

        return self._post_tokenizer(f" {line} ")

# %%
import collections
import math


def get_ngrams(segment, max_order):
  """Extracts all n-grams upto a given maximum order from an input segment.

  Args:
    segment: text segment from which n-grams will be extracted.
    max_order: maximum length in tokens of the n-grams returned by this
        methods.

  Returns:
    The Counter containing all n-grams upto max_order in segment
    with a count of how many times each n-gram occurred.
  """
  ngram_counts = collections.Counter()
  for order in range(1, max_order + 1):
    for i in range(0, len(segment) - order + 1):
      ngram = tuple(segment[i:i+order])
      ngram_counts[ngram] += 1
  return ngram_counts


def compute_bleu(reference_corpus, translation_corpus, max_order=4):
  """Computes BLEU score of translated segments against one or more references.

  Args:
    reference_corpus: list of lists of references for each translation. Each
        reference should be tokenized into a list of tokens.
    translation_corpus: list of translations to score. Each translation
        should be tokenized into a list of tokens.
    max_order: Maximum n-gram order to use when computing BLEU score.

  Returns:
    3-Tuple with the BLEU score, n-gram precisions, geometric mean of n-gram
    precisions and brevity penalty.
  """
  matches_by_order = [0] * max_order
  possible_matches_by_order = [0] * max_order
  reference_length = 0
  translation_length = 0
  for (references, translation) in zip(reference_corpus,
                                       translation_corpus):
    reference_length += min(len(r) for r in references)
    translation_length += len(translation)

    merged_ref_ngram_counts = collections.Counter()
    for reference in references:
      merged_ref_ngram_counts |= get_ngrams(reference, max_order)
    translation_ngram_counts = get_ngrams(translation, max_order)
    overlap = translation_ngram_counts & merged_ref_ngram_counts
    for ngram in overlap:
      matches_by_order[len(ngram)-1] += overlap[ngram]
    for order in range(1, max_order+1):
      possible_matches = len(translation) - order + 1
      if possible_matches > 0:
        possible_matches_by_order[order-1] += possible_matches

  precisions = [0] * max_order
  for i in range(0, max_order):
      if possible_matches_by_order[i] > 0:
        precisions[i] = (float(matches_by_order[i]) /
                         possible_matches_by_order[i])
      else:
        precisions[i] = 0.0

  if min(precisions) > 0:
    ## TO_DO: compute the geometric mean of all modified precision scores
      geo_mean = math.exp(sum(math.log(p) for p in precisions) / max_order)
  else:
      geo_mean = 0


  ## TO_DO: compute the brevity penalty (BP)
  ratio = translation_length / reference_length
  if ratio > 1.0:
      bp = 1.0
  else:
      bp = math.exp(1.0 - 1.0 / ratio)

  # final bleu score
  bleu = geo_mean * bp

  return (bleu, precisions, bp, ratio, translation_length, reference_length)

# %%
# Evaluation
def compute_bleu_score(predictions, references, tokenizer=Tokenizer13a(), max_order=4):
      # if only one reference is provided make sure we still use list of lists
      if isinstance(references[0], str):
          references = [[ref] for ref in references]

      references = [[tokenizer(r) for r in ref] for ref in references]
      predictions = [tokenizer(p) for p in predictions]
      score = compute_bleu(
          reference_corpus=references, translation_corpus=predictions, max_order=max_order)
      (bleu, precisions, bp, ratio, translation_length, reference_length) = score
      return {
          "bleu": bleu,
          "precisions": precisions,
          "brevity_penalty": bp,
          "length_ratio": ratio,
          "translation_length": translation_length,
          "reference_length": reference_length,
      }

# %% [markdown]
# A small example for real evaluation, feel free to change the final_predictions funtion to make it more adaptable.

# %%
references = french_sentences[:5]
predictions = [final_predictions(re.sub(r'[^\w]', ' ', txt)) for txt in english_sentences[:5]]
compute_bleu_score(predictions, references, max_order=2)
# Out:
# {'bleu': 0.5901239588230737,
#  'precisions': [0.7941176470588235, 0.5714285714285714],
#  'brevity_penalty': 0.8760317528329519,
#  'length_ratio': 0.8831168831168831,
#  'translation_length': 68,
#  'reference_length': 77}

# %% [markdown]
# ## Exercises:
#
# * Please complete the code under **TO_DO**
# * Complete the evaluation metrics (BLEU) and evaluate the whole dataset.
# * Train with more epochs. Does it improve the translations?
# * Change the architectures of the neural network, Does it improve the translations? For example:
#     * change the number of GRU layers
#     * change embedding-size
#     * try Bidirectional-RNN
# * Please finally submit the notebook with the best architecture settings that you found and comment your results.

# %% [markdown]
# ## 1) EUROPARL Dataset import

# %%
# !wget https://www.statmt.org/europarl/v7/fr-en.tgz
# !tar -xzf fr-en.tgz
# Out:
# --2024-06-18 18:38:32--  https://www.statmt.org/europarl/v7/fr-en.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.32.28
# Connecting to www.statmt.org (www.statmt.org)|129.215.32.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202718517 (193M) [application/x-gzip]
# Saving to: ‘fr-en.tgz’
#
# fr-en.tgz           100%[===================>] 193.33M  88.0MB/s    in 2.2s
#
# 2024-06-18 18:38:35 (88.0 MB/s) - ‘fr-en.tgz’ saved [202718517/202718517]

# %%
### Téléchargement du dataset ###
english_path='/content/europarl-v7.fr-en.en'
french_path='/content/europarl-v7.fr-en.fr'

def load_data(path):
  input_file = os.path.join(path)
  with open(input_file, "r") as f:
    data = f.read()
  return data.split('\n')

english_sentences = load_data(english_path)
french_sentences = load_data(french_path)

num_sentences = 15000
english_sentences = english_sentences[:num_sentences]
french_sentences = french_sentences[:num_sentences]

print("Anglais : ", english_sentences[:3])
print(len(english_sentences))
print("Français : ", french_sentences[:3])
print(len(french_sentences))
# Out:
# Anglais :  ['Resumption of the session', 'I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.', "Although, as you will have seen, the dreaded 'millennium bug' failed to materialise, still the people in a number of countries suffered a series of natural disasters that truly were dreadful."]
# 15000
# Français :  ['Reprise de la session', 'Je déclare reprise la session du Parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances.', 'Comme vous avez pu le constater, le grand "bogue de l\'an 2000" ne s\'est pas produit. En revanche, les citoyens d\'un certain nombre de nos pays ont été victimes de catastrophes naturelles qui ont vraiment été terribles.']
# 15000

# %%
new_english_sentences = english_sentences[:5]

text_tokenizer = tokenize(new_english_sentences)
print(text_tokenizer.word_index)
text_tokenized = text_tokenizer.texts_to_sequences(new_english_sentences)

for sample_i, (sent, token_sent) in enumerate(zip(new_english_sentences, text_tokenized)):
  print('Sequence {} in x'.format(sample_i + 1))
  print('  Input:  {}'.format(sent))
  print('  Output: {}'.format(token_sent))
# Out:
# {'the': 1, 'of': 2, 'a': 3, 'in': 4, 'you': 5, 'session': 6, 'i': 7, 'on': 8, 'to': 9, 'have': 10, 'european': 11, 'like': 12, 'that': 13, 'as': 14, 'number': 15, 'countries': 16, 'requested': 17, 'this': 18, 'resumption': 19, 'declare': 20, 'resumed': 21, 'parliament': 22, 'adjourned': 23, 'friday': 24, '17': 25, 'december': 26, '1999': 27, 'and': 28, 'would': 29, 'once': 30, 'again': 31, 'wish': 32, 'happy': 33, 'new': 34, 'year': 35, 'hope': 36, 'enjoyed': 37, 'pleasant': 38, 'festive': 39, 'period': 40, 'although': 41, 'will': 42, 'seen': 43, 'dreaded': 44, "'millennium": 45, "bug'": 46, 'failed': 47, 'materialise': 48, 'still': 49, 'people': 50, 'suffered': 51, 'series': 52, 'natural': 53, 'disasters': 54, 'truly': 55, 'were': 56, 'dreadful': 57, 'debate': 58, 'subject': 59, 'course': 60, 'next': 61, 'few': 62, 'days': 63, 'during': 64, 'part': 65, 'meantime': 66, 'should': 67, 'observe': 68, "minute'": 69, 's': 70, 'silence': 71, 'members': 72, 'behalf': 73, 'all': 74, 'victims': 75, 'concerned': 76, 'particularly': 77, 'those': 78, 'terrible': 79, 'storms': 80, 'various': 81, 'union': 82}
# Sequence 1 in x
#   Input:  Resumption of the session
#   Output: [19, 2, 1, 6]
# Sequence 2 in x
#   Input:  I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.
#   Output: [7, 20, 21, 1, 6, 2, 1, 11, 22, 23, 8, 24, 25, 26, 27, 28, 7, 29, 12, 30, 31, 9, 32, 5, 3, 33, 34, 35, 4, 1, 36, 13, 5, 37, 3, 38, 39, 40]
# Sequence 3 in x
#   Input:  Although, as you will have seen, the dreaded 'millennium bug' failed to materialise, still the people in a number of countries suffered a series of natural disasters that truly were dreadful.
#   Output: [41, 14, 5, 42, 10, 43, 1, 44, 45, 46, 47, 9, 48, 49, 1, 50, 4, 3, 15, 2, 16, 51, 3, 52, 2, 53, 54, 13, 55, 56, 57]
# Sequence 4 in x
#   Input:  You have requested a debate on this subject in the course of the next few days, during this part-session.
#   Output: [5, 10, 17, 3, 58, 8, 18, 59, 4, 1, 60, 2, 1, 61, 62, 63, 64, 18, 65, 6]
# Sequence 5 in x
#   Input:  In the meantime, I should like to observe a minute' s silence, as a number of Members have requested, on behalf of all the victims concerned, particularly those of the terrible storms, in the various countries of the European Union.
#   Output: [4, 1, 66, 7, 67, 12, 9, 68, 3, 69, 70, 71, 14, 3, 15, 2, 72, 10, 17, 8, 73, 2, 74, 1, 75, 76, 77, 78, 2, 1, 79, 80, 4, 1, 81, 16, 2, 1, 11, 82]

# %% [markdown]
# ## Data Préprocessing

# %%
preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer =\
    preprocess(english_sentences, french_sentences)

max_english_sequence_length = preproc_english_sentences.shape[1]
max_french_sequence_length = preproc_french_sentences.shape[1]
english_vocab_size = len(english_tokenizer.word_index)
french_vocab_size = len(french_tokenizer.word_index)


print('Data Preprocessed.')
print("Max English sentence length:", max_english_sequence_length)
print("Max French sentence length:", max_french_sequence_length)
print("English vocabulary size:", english_vocab_size)
print("French vocabulary size:", french_vocab_size)

print("Are all English sequences of the same length?", all(len(seq) == max_english_sequence_length for seq in preproc_english_sentences))
print("Are all French sequences of the same length?", all(len(seq) == max_french_sequence_length for seq in preproc_french_sentences))
# Out:
# Data Preprocessed.
# Max English sentence length: 150
# Max French sentence length: 147
# English vocabulary size: 13086
# French vocabulary size: 18974
# Are all English sequences of the same length? True
# Are all French sequences of the same length? True

# %%
# english_tokenizer_dataset.word_index
# preproc_french_sentences_dataset

# %%
def logits_to_text(logits, tokenizer):
  index_to_words = {id: word for word, id in tokenizer.word_index.items()}
  index_to_words[0] = '<PAD>'

  #So basically we are predicting output for a given word and then selecting best answer
  #Then selecting that label we reverse-enumerate the word from id
  return ' '.join([index_to_words[prediction] for prediction in np.argmax(logits, 1)])

# %% [markdown]
# ## Training

# %%
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a RNN model using word embedding on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """

    ## TO_DO: Improve the layers (See Exercise 4)
    model = Sequential()
    model.add(Embedding(english_vocab_size, 256, input_length=input_shape[1], input_shape=input_shape[1:]))
    model.add(GRU(256, return_sequences=True))
    model.add(TimeDistributed(Dense(1024, activation='relu')))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(french_vocab_size, activation='softmax')))

    return model

# %%
# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, preproc_french_sentences.shape[1])
print(f"Shape before reshaping: {tmp_x.shape}")
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2]))
print(f"Shape after reshaping: {tmp_x.shape}")
# Out:
# Shape before reshaping: (2000, 138)
# Shape after reshaping: (2000, 138)

# %%
learning_rate = 0.005

simple_rnn_model2 = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index)+1,
    len(french_tokenizer.word_index)+1)

simple_rnn_model2.compile(loss=sparse_categorical_crossentropy,
                         optimizer=Adam(learning_rate),
                         metrics=['accuracy'])

simple_rnn_model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 138, 256)          1271040
#
#  gru_5 (GRU)                 (None, 138, 256)          394752
#
#  time_distributed_10 (TimeD  (None, 138, 1024)         263168
#  istributed)
#
#  dropout_5 (Dropout)         (None, 138, 1024)         0
#
#  time_distributed_11 (TimeD  (None, 138, 6588)         6752700
#  istributed)
#
# =================================================================
# Total params: 8681660 (33.12 MB)
# Trainable params: 8681660 (33.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=simple_rnn_model2.fit(tmp_x, preproc_french_sentences, batch_size=128, epochs=5, validation_split=0.3)
# Out:
# Epoch 1/5
# 11/11 [==============================] - 10s 540ms/step - loss: 3.4779 - accuracy: 0.7201 - val_loss: 1.5164 - val_accuracy: 0.8083
# Epoch 2/5
# 11/11 [==============================] - 4s 365ms/step - loss: 1.5929 - accuracy: 0.7955 - val_loss: 1.4554 - val_accuracy: 0.8085
# Epoch 3/5
# 11/11 [==============================] - 6s 550ms/step - loss: 1.4676 - accuracy: 0.7958 - val_loss: 1.3974 - val_accuracy: 0.8119
# Epoch 4/5
# 11/11 [==============================] - 5s 455ms/step - loss: 1.4160 - accuracy: 0.7977 - val_loss: 1.3898 - val_accuracy: 0.8118
# Epoch 5/5
# 11/11 [==============================] - 6s 548ms/step - loss: 1.3908 - accuracy: 0.7988 - val_loss: 1.3993 - val_accuracy: 0.8113

# %% [markdown]
# ## 2) Dataset evaluation

# %%
from tqdm import tqdm
def final_predictions(text):
  y_id_to_word = {value: key for key, value in french_tokenizer.word_index.items()}
  y_id_to_word[0] = '<PAD>'

  sentence = [english_tokenizer.word_index[word.lower()] for word in text.split()]
  sentence = pad_sequences([sentence], maxlen=preproc_french_sentences.shape[-2], padding='post')
  french_translation = logits_to_text(simple_rnn_model.predict(sentence[:1], verbose=0)[0], french_tokenizer)
  return re.split(r"\s*<PAD>", french_translation, 1)[0]

references = french_sentences[:5]
predictions = [final_predictions(re.sub(r'[^\w]', ' ', txt)) for txt in english_sentences[:5]]
compute_bleu_score(predictions, references, max_order=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-2fcca42e46c6> in <cell line: 12>()
#      10
#      11 references = french_sentences[:5]
# ---> 12 predictions = [final_predictions(re.sub(r'[^\w]', ' ', txt)) for txt in english_sentences[:5]]
#      13 compute_bleu_score(predictions, references, max_order=2)
#
# <ipython-input-117-2fcca42e46c6> in <listcomp>(.0)
#      10
#      11 references = french_sentences[:5]
# ---> 12 predictions = [final_predictions(re.sub(r'[^\w]', ' ', txt)) for txt in english_sentences[:5]]
#      13 compute_bleu_score(predictions, references, max_order=2)
#
# <ipython-input-117-2fcca42e46c6> in final_predictions(text)
#       4   y_id_to_word[0] = '<PAD>'
#       5
# ----> 6   sentence = [english_tokenizer.word_index[word.lower()] for word in text.split()]
#       7   sentence = pad_sequences([sentence], maxlen=preproc_french_sentences.shape[-2], padding='post')
#       8   french_translation = logits_to_text(simple_rnn_model.predict(sentence[:1], verbose=0)[0], french_tokenizer)
#
# <ipython-input-117-2fcca42e46c6> in <listcomp>(.0)
#       4   y_id_to_word[0] = '<PAD>'
#       5
# ----> 6   sentence = [english_tokenizer.word_index[word.lower()] for word in text.split()]
#       7   sentence = pad_sequences([sentence], maxlen=preproc_french_sentences.shape[-2], padding='post')
#       8   french_translation = logits_to_text(simple_rnn_model.predict(sentence[:1], verbose=0)[0], french_tokenizer)
#
# KeyError: 'bug'

# %% [markdown]
# ## **JE N'AI PAS RÉUSSI A RESOUDRE L'ERREUR CI-DESSUS (KeyError: 'bug') QUI M'EMPÊCHAIT DE FAIRE DES PRRRÉDICTIONS AVEC LE NOUVEAU DATASET, DE CE FAIT J'AI DÛ FAIRE LA SUITE DU TP AVEC LE SAMPLE DATASET**

# %%
references = french_sentences

predictions = []
for txt in tqdm(english_sentences[:2000], desc="Prédictions"):
  clean_txt = re.sub(r'[^\w\']', ' ', txt)
  prediction = final_predictions(clean_txt)
  predictions.append(prediction)

compute_bleu_score(predictions, references, max_order=2)
# Out:
# Prédictions: 100%|██████████| 2000/2000 [02:35<00:00, 12.84it/s]
# {'bleu': 0.714328185625965,
#  'precisions': [0.9071064564022311, 0.7527594782077571],
#  'brevity_penalty': 0.8644513190877329,
#  'length_ratio': 0.8728590942523905,
#  'translation_length': 24921,
#  'reference_length': 28551}

# %% [markdown]
# ## Premiers résultats avec RNN (par manque de ressources computationnelles, je n'utilise que 2000 phrases)
#
# Caractéristiques du RNN :
# - batch_size=1024,
# - epochs=10,
# - validation_split=0.2,
# - learning_rate=0.005,
# - 5 couches : embedding/GRU/TimeDistr/Dropout/TimeDistr
#
# On a :
#
# **Bleu** : 0.7143
#
# **Précisions** : [0.9071, 0.7526]
#
# **brevity_penalty** : 0.8645
#
# **length_ratio** : 0.8729
#
# **translation_length** : 24921
#
# **reference_length** : 28551

# %% [markdown]
# ## 3) Train with more epochs. Does it improve the translations?

# %%
simple_rnn_model = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index)+1,
    len(french_tokenizer.word_index)+1)

simple_rnn_model.compile(loss=sparse_categorical_crossentropy,
                         optimizer=Adam(learning_rate),
                         metrics=['accuracy'])

history=simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=20, validation_split=0.2)

predictions = []
for txt in tqdm(english_sentences[:2000], desc="Prédictions"):
  clean_txt = re.sub(r'[^\w\']', ' ', txt)
  prediction = final_predictions(clean_txt)
  predictions.append(prediction)

compute_bleu_score(predictions, references, max_order=2)
# Out:
# Epoch 1/20
# 108/108 [==============================] - 12s 77ms/step - loss: 1.3514 - accuracy: 0.6830 - val_loss: 0.4787 - val_accuracy: 0.8450
# Epoch 2/20
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4005 - accuracy: 0.8693 - val_loss: 0.2982 - val_accuracy: 0.8985
# Epoch 3/20
# 108/108 [==============================] - 6s 57ms/step - loss: 0.2893 - accuracy: 0.9032 - val_loss: 0.2458 - val_accuracy: 0.9154
# Epoch 4/20
# 108/108 [==============================] - 7s 62ms/step - loss: 0.2454 - accuracy: 0.9169 - val_loss: 0.2147 - val_accuracy: 0.9261
# Epoch 5/20
# 108/108 [==============================] - 7s 64ms/step - loss: 0.2209 - accuracy: 0.9242 - val_loss: 0.2023 - val_accuracy: 0.9300
# Epoch 6/20
# 108/108 [==============================] - 6s 59ms/step - loss: 0.2068 - accuracy: 0.9284 - val_loss: 0.1968 - val_accuracy: 0.9317
# Epoch 7/20
# 108/108 [==============================] - 6s 59ms/step - loss: 0.1964 - accuracy: 0.9314 - val_loss: 0.1895 - val_accuracy: 0.9339
# Epoch 8/20
# 108/108 [==============================] - 7s 61ms/step - loss: 0.1900 - accuracy: 0.9331 - val_loss: 0.1888 - val_accuracy: 0.9336
# Epoch 9/20
# 108/108 [==============================] - 6s 60ms/step - loss: 0.1867 - accuracy: 0.9340 - val_loss: 0.1836 - val_accuracy: 0.9359
# Epoch 10/20
# 108/108 [==============================] - 6s 60ms/step - loss: 0.1798 - accuracy: 0.9360 - val_loss: 0.1825 - val_accuracy: 0.9353
# Epoch 11/20
# 108/108 [==============================] - 7s 62ms/step - loss: 0.1784 - accuracy: 0.9360 - val_loss: 0.1798 - val_accuracy: 0.9362
# Epoch 12/20
# 108/108 [==============================] - 7s 61ms/step - loss: 0.1735 - accuracy: 0.9373 - val_loss: 0.1776 - val_accuracy: 0.9375
# Epoch 13/20
# 108/108 [==============================] - 6s 59ms/step - loss: 0.1719 - accuracy: 0.9376 - val_loss: 0.1835 - val_accuracy: 0.9361
# Epoch 14/20
# 108/108 [==============================] - 6s 60ms/step - loss: 0.1727 - accuracy: 0.9374 - val_loss: 0.1767 - val_accuracy: 0.9376
# Epoch 15/20
# 108/108 [==============================] - 6s 58ms/step - loss: 0.1697 - accuracy: 0.9383 - val_loss: 0.1783 - val_accuracy: 0.9378
# Epoch 16/20
# 108/108 [==============================] - 6s 60ms/step - loss: 0.1725 - accuracy: 0.9375 - val_loss: 0.1883 - val_accuracy: 0.9353
# Epoch 17/20
# 108/108 [==============================] - 6s 59ms/step - loss: 0.1710 - accuracy: 0.9379 - val_loss: 0.1786 - val_accuracy: 0.9382
# Epoch 18/20
# 108/108 [==============================] - 6s 59ms/step - loss: 0.1631 - accuracy: 0.9399 - val_loss: 0.1795 - val_accuracy: 0.9388
# Epoch 19/20
# 108/108 [==============================] - 6s 59ms/step - loss: 0.1623 - accuracy: 0.9402 - val_loss: 0.1822 - val_accuracy: 0.9374
# Epoch 20/20
# 108/108 [==============================] - 6s 60ms/step - loss: 0.1640 - accuracy: 0.9396 - val_loss: 0.1784 - val_accuracy: 0.9384
# Prédictions: 100%|██████████| 2000/2000 [02:30<00:00, 13.29it/s]
# {'bleu': 0.716483611506371,
#  'precisions': [0.9098103808452515, 0.757076708020269],
#  'brevity_penalty': 0.8632982779433895,
#  'length_ratio': 0.8718433680081258,
#  'translation_length': 24892,
#  'reference_length': 28551}

# %% [markdown]
# Avec les mêmes configurations mais avec 20 épochs au lieu de 10, on a les métriques suivantes
#
# **Bleu** : 0.7165
#
# **Précisions** : [0.9098, 0.7571]
#
# **brevity_penalty** : 0.8633
#
# **length_ratio** : 0.8718
#
# **translation_length** : 24892
#
# **reference_length** : 28551
#
# On obtient quasiment le même BLEU score et des métriques similiraies à un epsilon près. Le nombre d'épochs (au dela d'un seuil) n'est plus si déterminant que cela.

# %% [markdown]
# ## 4) Change the architectures of the neural network, Does it improve the translations?

# %% [markdown]
# ### -->  Number of GRU layers = 3

# %%
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    model = Sequential()
    model.add(Embedding(english_vocab_size, 256, input_length=input_shape[1], input_shape=input_shape[1:]))
    model.add(GRU(256, return_sequences=True))
    model.add(GRU(256, return_sequences=True))
    model.add(GRU(256, return_sequences=True))
    model.add(TimeDistributed(Dense(1024, activation='relu')))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(french_vocab_size, activation='softmax')))

    return model

simple_rnn_model = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index)+1,
    len(french_tokenizer.word_index)+1)

simple_rnn_model.compile(loss=sparse_categorical_crossentropy,
                         optimizer=Adam(learning_rate),
                         metrics=['accuracy'])

history=simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=10, validation_split=0.2)

predictions = []
for txt in tqdm(english_sentences[:2000], desc="Prédictions"):
  clean_txt = re.sub(r'[^\w\']', ' ', txt)
  prediction = final_predictions(clean_txt)
  predictions.append(prediction)

compute_bleu_score(predictions, references, max_order=2)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 23s 125ms/step - loss: 1.6213 - accuracy: 0.6284 - val_loss: 0.5898 - val_accuracy: 0.8278
# Epoch 2/10
# 108/108 [==============================] - 11s 104ms/step - loss: 0.4460 - accuracy: 0.8630 - val_loss: 0.3086 - val_accuracy: 0.9014
# Epoch 3/10
# 108/108 [==============================] - 11s 101ms/step - loss: 0.2946 - accuracy: 0.9050 - val_loss: 0.2495 - val_accuracy: 0.9176
# Epoch 4/10
# 108/108 [==============================] - 11s 106ms/step - loss: 0.2413 - accuracy: 0.9198 - val_loss: 0.2118 - val_accuracy: 0.9284
# Epoch 5/10
# 108/108 [==============================] - 11s 103ms/step - loss: 0.2139 - accuracy: 0.9274 - val_loss: 0.2038 - val_accuracy: 0.9305
# Epoch 6/10
# 108/108 [==============================] - 10s 97ms/step - loss: 0.2048 - accuracy: 0.9299 - val_loss: 0.1950 - val_accuracy: 0.9332
# Epoch 7/10
# 108/108 [==============================] - 11s 101ms/step - loss: 0.1933 - accuracy: 0.9327 - val_loss: 0.1909 - val_accuracy: 0.9346
# Epoch 8/10
# 108/108 [==============================] - 11s 104ms/step - loss: 0.1843 - accuracy: 0.9350 - val_loss: 0.1855 - val_accuracy: 0.9359
# Epoch 9/10
# 108/108 [==============================] - 11s 98ms/step - loss: 0.1835 - accuracy: 0.9353 - val_loss: 0.1917 - val_accuracy: 0.9344
# Epoch 10/10
# 108/108 [==============================] - 11s 97ms/step - loss: 0.1829 - accuracy: 0.9352 - val_loss: 0.1837 - val_accuracy: 0.9372
# Prédictions: 100%|██████████| 2000/2000 [02:38<00:00, 12.64it/s]
# {'bleu': 0.7143483148839451,
#  'precisions': [0.9078424286230574, 0.7534384141815482],
#  'brevity_penalty': 0.8637357732958085,
#  'length_ratio': 0.8722286434800882,
#  'translation_length': 24903,
#  'reference_length': 28551}

# %% [markdown]
# **Bleu** : 0.7143
#
# **Précisions** : [0.9078, 0.7534]
#
# **brevity_penalty** : 0.8637
#
# **length_ratio** : 0.8722
#
# **translation_length** : 24903
#
# **reference_length** : 28551
#
# On remarque que les résultats n'évoluent pas grandement non plus en rajoutant des couches GRU. On aurait pu étudier l'impact du nombre d'unités de la couche GRU plutôt que sur le nombre de couches.

# %% [markdown]
# ### -->  Embedding size = 512

# %%
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    model = Sequential()
    model.add(Embedding(english_vocab_size, 512, input_length=input_shape[1], input_shape=input_shape[1:]))
    model.add(GRU(256, return_sequences=True))
    model.add(TimeDistributed(Dense(1024, activation='relu')))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(french_vocab_size, activation='softmax')))

    return model

simple_rnn_model = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index)+1,
    len(french_tokenizer.word_index)+1)

simple_rnn_model.compile(loss=sparse_categorical_crossentropy,
                         optimizer=Adam(learning_rate),
                         metrics=['accuracy'])

history=simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=10, validation_split=0.2)

predictions = []
for txt in tqdm(english_sentences[:2000], desc="Prédictions"):
  clean_txt = re.sub(r'[^\w\']', ' ', txt)
  prediction = final_predictions(clean_txt)
  predictions.append(prediction)

compute_bleu_score(predictions, references, max_order=2)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 15s 95ms/step - loss: 1.2938 - accuracy: 0.6957 - val_loss: 0.4447 - val_accuracy: 0.8563
# Epoch 2/10
# 108/108 [==============================] - 7s 68ms/step - loss: 0.3770 - accuracy: 0.8767 - val_loss: 0.2846 - val_accuracy: 0.9055
# Epoch 3/10
# 108/108 [==============================] - 7s 67ms/step - loss: 0.2722 - accuracy: 0.9092 - val_loss: 0.2302 - val_accuracy: 0.9218
# Epoch 4/10
# 108/108 [==============================] - 7s 67ms/step - loss: 0.2323 - accuracy: 0.9213 - val_loss: 0.2125 - val_accuracy: 0.9273
# Epoch 5/10
# 108/108 [==============================] - 7s 67ms/step - loss: 0.2113 - accuracy: 0.9275 - val_loss: 0.1983 - val_accuracy: 0.9315
# Epoch 6/10
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1997 - accuracy: 0.9305 - val_loss: 0.1902 - val_accuracy: 0.9335
# Epoch 7/10
# 108/108 [==============================] - 7s 69ms/step - loss: 0.1921 - accuracy: 0.9325 - val_loss: 0.1874 - val_accuracy: 0.9346
# Epoch 8/10
# 108/108 [==============================] - 7s 66ms/step - loss: 0.1833 - accuracy: 0.9349 - val_loss: 0.1841 - val_accuracy: 0.9360
# Epoch 9/10
# 108/108 [==============================] - 7s 68ms/step - loss: 0.1796 - accuracy: 0.9359 - val_loss: 0.1811 - val_accuracy: 0.9365
# Epoch 10/10
# 108/108 [==============================] - 7s 69ms/step - loss: 0.1776 - accuracy: 0.9364 - val_loss: 0.1823 - val_accuracy: 0.9364
# Prédictions: 100%|██████████| 2000/2000 [02:38<00:00, 12.59it/s]
# {'bleu': 0.7152663616859067,
#  'precisions': [0.9074490287365549, 0.7548001396404259],
#  'brevity_penalty': 0.8642526006518635,
#  'length_ratio': 0.872683969037862,
#  'translation_length': 24916,
#  'reference_length': 28551}

# %% [markdown]
# **Bleu** : 0.7153
#
# **Précisions** : [0.9074, 0.7548]
#
# **brevity_penalty** : 0.8643
#
# **length_ratio** : 0.8727
#
# **translation_length** : 24916
#
# **reference_length** : 28551

# %% [markdown]
# ### -->  Bidirectional-RNN

# %%
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    model = Sequential()
    model.add(Embedding(english_vocab_size, 256, input_length=input_shape[1], input_shape=input_shape[1:]))
    model.add(Bidirectional(GRU(256, return_sequences=True)))
    model.add(TimeDistributed(Dense(1024, activation='relu')))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(french_vocab_size, activation='softmax')))

    return model

simple_rnn_model = embed_model(
    tmp_x.shape,
    preproc_french_sentences.shape[1],
    len(english_tokenizer.word_index)+1,
    len(french_tokenizer.word_index)+1)

simple_rnn_model.compile(loss=sparse_categorical_crossentropy,
                         optimizer=Adam(learning_rate),
                         metrics=['accuracy'])

history=simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=10, validation_split=0.2)

predictions = []
for txt in tqdm(english_sentences[:2000], desc="Prédictions"):
  clean_txt = re.sub(r'[^\w\']', ' ', txt)
  prediction = final_predictions(clean_txt)
  predictions.append(prediction)

compute_bleu_score(predictions, references, max_order=2)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 18s 118ms/step - loss: 1.2095 - accuracy: 0.7120 - val_loss: 0.3775 - val_accuracy: 0.8785
# Epoch 2/10
# 108/108 [==============================] - 10s 97ms/step - loss: 0.2965 - accuracy: 0.9046 - val_loss: 0.1882 - val_accuracy: 0.9388
# Epoch 3/10
# 108/108 [==============================] - 10s 94ms/step - loss: 0.1759 - accuracy: 0.9437 - val_loss: 0.1281 - val_accuracy: 0.9595
# Epoch 4/10
# 108/108 [==============================] - 10s 89ms/step - loss: 0.1253 - accuracy: 0.9609 - val_loss: 0.0999 - val_accuracy: 0.9694
# Epoch 5/10
# 108/108 [==============================] - 10s 88ms/step - loss: 0.1000 - accuracy: 0.9689 - val_loss: 0.0837 - val_accuracy: 0.9744
# Epoch 6/10
# 108/108 [==============================] - 10s 94ms/step - loss: 0.0835 - accuracy: 0.9742 - val_loss: 0.0761 - val_accuracy: 0.9776
# Epoch 7/10
# 108/108 [==============================] - 10s 94ms/step - loss: 0.0714 - accuracy: 0.9780 - val_loss: 0.0682 - val_accuracy: 0.9803
# Epoch 8/10
# 108/108 [==============================] - 10s 91ms/step - loss: 0.0635 - accuracy: 0.9802 - val_loss: 0.0677 - val_accuracy: 0.9812
# Epoch 9/10
# 108/108 [==============================] - 10s 88ms/step - loss: 0.0598 - accuracy: 0.9814 - val_loss: 0.0642 - val_accuracy: 0.9824
# Epoch 10/10
# 108/108 [==============================] - 10s 93ms/step - loss: 0.0542 - accuracy: 0.9830 - val_loss: 0.0619 - val_accuracy: 0.9830
# Prédictions: 100%|██████████| 2000/2000 [02:48<00:00, 11.90it/s]
# {'bleu': 0.8034979934093085,
#  'precisions': [0.9785226816539543, 0.8838061981667394],
#  'brevity_penalty': 0.8640140935655726,
#  'length_ratio': 0.872473818780428,
#  'translation_length': 24910,
#  'reference_length': 28551}

# %% [markdown]
# **Bleu** : 0.8035
#
# **Précisions** : [0.9785, 0.8838]
#
# **brevity_penalty** : 0.8640
#
# **length_ratio** :  0.8725
#
# **translation_length** : 24910
#
# **reference_length** : 28551

# %% [markdown]
# Parmi les différents modèles que nous avons testés, nous avons pu voir que le modèle RNN bidirectionnel était le plus efficace au vu des métriques car offrait le meilleur BLUE score avec environ 0.1 de plus que le second meilleur modèle. De plus il offrait une meilleure range de précision.
